# %%
import os
os.environ['USE_PYGEOS'] = '0'
import requests
import pandas as pd
import geopandas as gpd
import datetime
from shapely import wkt, wkb
import polyline
from shapely.geometry import LineString, Point
import boto3
import numpy as np
import random
import json

# %%
def random_points_within(poly, num_points):
    min_x, min_y, max_x, max_y = poly.bounds

    points = []

    while len(points) < num_points:
        random_point = Point([random.uniform(min_x, max_x), random.uniform(min_y, max_y)])
        if (random_point.within(poly)):
            points.append(random_point)

    return points

def generate_points_within_tm_boundary(tm_boundary, trimet_crs):
    '''
    generate 2 points and make sure they are > 1 mile apart
    '''
    
    #the length of the line connecting the two points is the 
    #distance between them (as crow flies)
    #convert crs if not already
    tm_boundary_proj = tm_boundary.to_crs(trimet_crs)
    dist_btw_points = 0
    while dist_btw_points < 1:
        points_list = random_points_within(tm_boundary_proj.unary_union, 2)
        dist_btw_points = LineString(points_list).length/5280

    df = pd.DataFrame()
    df['points'] = points_list
    df['points'] = df['points'].apply(Point)
    gdf_points = gpd.GeoDataFrame(df,crs=trimet_crs ,geometry='points')
    gdf_points_reproject = gdf_points.to_crs("EPSG:4326")

    return (gdf_points_reproject, dist_btw_points)

def call_planner(fromPlace, toPlace):
    ''' 
    fromPlace = "lat, lon"
    toPlace = "lat,lon"
    '''
    date = datetime.datetime.now().strftime("%Y-%m-%d")
    base_url = "https://maps.trimet.org/otp_mod/plan"
    time="12:00"
    mode="WALK,BUS,TRAM,RAIL,GONDOLA"
    maxWalkDistance=5280/2
    walkSpeed=1.34
    numItineraries=3
    r = requests.get(url=base_url, params={'fromPlace':fromPlace, 'toPlace':toPlace, 'date':date, 'time':time
                                    ,'mode':mode, 'maxWalkDistance':maxWalkDistance, 'walkSpeed':walkSpeed
                                    ,'numItineraries':numItineraries})
    assert(r.status_code==200)
    return r.json()

def decode_create_leg_line(encoded_linestring):
    '''google polyline encoded linestring'''
    reformatted_coords = []
    original_coords = polyline.decode(encoded_linestring)
    for coord in original_coords:
        reformatted_coords.append((coord[1],coord[0]))
    return LineString(reformatted_coords)

def get_itinerary_paths(planner_response):
    ''' 
    planner_response = json_response from TriMet trip planner
    '''
    itineraries_df = pd.DataFrame()
    for itin_idx, itinerary in enumerate(planner_response['plan']['itineraries']):
        totalTime = itinerary['duration']
        walkTime = itinerary['walkTime']
        transitTime = itinerary['transitTime']
        waitingTime = itinerary['waitingTime']
        walkDistance = itinerary['walkDistance']
        for leg_idx, leg in enumerate(itinerary['legs']):
            route_id = leg.get('routeId','WALK').split(":")[-1]
            mode = leg['mode']
            fromName = leg['from']['name']
            toName = leg['to']['name']
            fromStopCode = leg['from'].get('stopCode','')
            toStopCode = leg['to'].get('stopCode','')
            legGeometry = decode_create_leg_line(leg['legGeometry']['points'])
            leg_df = pd.DataFrame([[itin_idx, totalTime, walkTime, transitTime, waitingTime, walkDistance,
                                   leg_idx, route_id, mode, fromStopCode, fromName, toStopCode, toName,
                                   legGeometry]],
                                   columns=['itin_idx', 'totalTime', 'walkTime', 'transitTime', 'waitingTime', 'walkDistance',
                                   'leg_id', 'route_id', 'mode', 'fromStopCode', 'fromName', 'toStopCode', 'toName',
                                   'legGeometry'])
            itineraries_df = pd.concat([itineraries_df,leg_df])
    return itineraries_df

# %% [markdown]
# ## basic plan generate random points within trimet service area
# **Steps**
# 1. get TriMet service area
# 2. generate 2 points
# 3. check that points are not within 1 mile of each other (as the crow flies)
#
# ## advanced plan generate random point within 2 portland block groups
# **Steps**
# 1. Download block groups
# 2. get TriMet service area
# 3. generate points within two separate block groups - advanced no adjacent?

# %%
tm_boundary = gpd.read_file("gis/export/tm_route_buffer_bounds.geojson")
tm_boundary.head(3)
# Out:
#                     description
# 0  trimet_route_buffer_boundary  \
#
#                                             geometry
# 0  POLYGON ((-122.73188 45.54927, -122.73217 45.5...

# %%
trimet_crs = "EPSG:2913"

# %%
gdf_points, dist_btw_points = generate_points_within_tm_boundary(tm_boundary, trimet_crs)
gdf_points.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df6863befb5943f8c5b61888cacdc42c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df6863befb5943f8c5b61888cacdc42c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df6863befb5943f8c5b61888cacdc42c = L.map(
#                 &quot;map_df6863befb5943f8c5b61888cacdc42c&quot;,
#                 {
#                     center: [45.477773552693236, -122.84548914724375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_df6863befb5943f8c5b61888cacdc42c);
#
#
#
#
#
#             var tile_layer_47133eee6ea2924e2828896c8a0a0812 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df6863befb5943f8c5b61888cacdc42c);
#
#
#             map_df6863befb5943f8c5b61888cacdc42c.fitBounds(
#                 [[45.42964247340347, -122.96995296563675], [45.52590463198301, -122.72102532885076]],
#                 {}
#             );
#
#
#         function geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_53bc3926badd1cc54d7f33d3a0ccbf22.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_53bc3926badd1cc54d7f33d3a0ccbf22 = L.geoJson(null, {
#                 onEachFeature: geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_onEachFeature,
#
#                 style: geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_styler,
#                 pointToLayer: geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_pointToLayer
#         });
#
#         function geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_add (data) {
#             geo_json_53bc3926badd1cc54d7f33d3a0ccbf22
#                 .addData(data)
#                 .addTo(map_df6863befb5943f8c5b61888cacdc42c);
#         }
#             geo_json_53bc3926badd1cc54d7f33d3a0ccbf22_add({&quot;bbox&quot;: [-122.96995296563675, 45.42964247340347, -122.72102532885076, 45.52590463198301], &quot;features&quot;: [{&quot;bbox&quot;: [-122.72102532885076, 45.42964247340347, -122.72102532885076, 45.42964247340347], &quot;geometry&quot;: {&quot;coordinates&quot;: [-122.72102532885076, 45.42964247340347], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-122.96995296563675, 45.52590463198301, -122.96995296563675, 45.52590463198301], &quot;geometry&quot;: {&quot;coordinates&quot;: [-122.96995296563675, 45.5259046319

# %%
gdf_points['points_str'] = gdf_points['points'].apply(lambda x: f"{round(x.y,6)}, {round(x.x,6)}")

# %%
fromplace, toplace = gdf_points['points_str'].to_numpy()

# %%
json_content = call_planner(fromplace, toplace)

# %%
json_content
# Out:
# {'requestParameters': {'date': '2023-05-05',
#   'mode': 'WALK,BUS,TRAM,RAIL,GONDOLA',
#   'walkSpeed': '1.34',
#   'fromPlace': '45.429642, -122.721025',
#   'toPlace': '45.525905, -122.969953',
#   'time': '12:00',
#   'maxWalkDistance': '2640.0',
#   'numItineraries': '3'},
#  'plan': {'date': 1683313200000,
#   'from': {'name': 'Origin',
#    'wheelchairBoarding': 'UNKNOWN',
#    'lon': -122.721025,
#    'lat': 45.429642,
#    'orig': '',
#    'vertexType': 'NORMAL'},
#   'to': {'name': 'Destination',
#    'wheelchairBoarding': 'UNKNOWN',
#    'lon': -122.969953,
#    'lat': 45.525905,
#    'orig': '',
#    'vertexType': 'NORMAL'},
#   'itineraries': [{'duration': 6741,
#     'startTime': 1683314480000,
#     'endTime': 1683321221000,
#     'walkTime': 1422,
#     'transitTime': 4491,
#     'waitingTime': 828,
#     'walkDistance': 1635.0370298365717,
#     'walkLimitExceeded': False,
#     'elevationLost': 22.00000000000002,
#     'elevationGained': 26.75000000000003,
#     'transfers': 1,
#     'fare': {'fare': {'regular': {'currency': {'symbol': '$',
#         'currency': 'USD',
#         'defaultFractionDigits': 2,
#         'currencyCode': 'USD'},
#        'cents': 250}},
#      'details': {'regular': []}},
#     'legs': [{'startTime': 1683314480000,
#       'endTime': 1683315133000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 655.756,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Origin',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.721025,
#        'lat': 45.429642,
#        'departure': 1683314480000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'to': {'name': 'Kerr & Touchstone',
#        'stopId': 'TriMet:10305',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '10305',
#        'lon': -122.714739,
#        'lat': 45.42813,
#        'arrival': 1683315133000,
#        'departure': 1683315134000,
#        'zoneId': 'B',
#        'stopIndex': 16,
#        'stopSequence': 17,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'e~gtGn}_lVMTEJIIIIGKIKGMGM`@u@DIBOBOLi@@MFQDKDGXSJMDM@AAKBI@GBK@M@O@GBA@YEABYD_@BODWRaAF[?G?E?CCCWUY]QQJYBMBW@GBG@E@E@CBELSDKHWBGLSHQBG@C@C@?@APGBCFODMFSBKBGBGBEFIRUPSTc@HOFOPq@@G?CACGE@IAQ@MBY?G',
#        'length': 90},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 653.0,
#       'transitLeg': False,
#       'steps': [{'distance': 17.487000000000002,
#         'relativeDirection': 'DEPART',
#         'streetName': 'path',
#         'absoluteDirection': 'NORTHWEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.72103143132752,
#         'lat': 45.42963664519159,
#         'elevation': [{'first': 0.0, 'second': 172.00284458479427},
#          {'first': 10.0, 'second': 173.3828445847943},
#          {'first': 11.62, 'second': 173.56284458479428},
#          {'first': 11.621, 'second': 179.15284458479428},
#          {'first': 17.491, 'second': 178.9828445847943}]},
#        {'distance': 41.36,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'Cellini Ct',
#         'absoluteDirection': 'NORTHEAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.7212013,
#         'lat': 45.4297392,
#         'elevation': [{'first': 0.0, 'second': 178.9828445847943},
#          {'first': 10.0, 'second': 180.25284458479427},
#          {'first': 20.0, 'second': 181.52284458479429},
#          {'first': 30.0, 'second': 182.77284458479429},
#          {'first': 41.37, 'second': 183.5128445847943}]},
#        {'distance': 121.489,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'Cellini',
#         'absoluteDirection': 'SOUTHEAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.7208406,
#         'lat': 45.4300097,
#         'elevation': [{'first': 0.0, 'second': 183.5128445847943},
#          {'first': 10.0, 'second': 183.5128445847943},
#          {'first': 20.0, 'second': 183.22284458479427},
#          {'first': 30.0, 'second': 182.78284458479428},
#          {'first': 40.0, 'second': 182.1428445847943},
#          {'first': 50.0, 'second': 181.8028445847943},
#          {'first': 60.0, 'second': 181.3828445847943},
#          {'first': 70.0, 'second': 180.99284458479428},
#          {'first': 80.0, 'second': 181.1728445847943},
#          {'first': 90.0, 'second': 181.4528445847943},
#          {'first': 100.0, 'second': 181.75284458479427},
#          {'first': 110.0, 'second': 182.34284458479428},
#          {'first': 120.24, 'second': 183.09284458479428},
#          {'first': 120.238, 'second': 183.09284458479428},
#          {'first': 121.488, 'second': 183.22284458479427}]},
#        {'distance': 44.717,
#         'relativeDirection': 'SLIGHTLY_LEFT',
#         'streetName': 'Cellini Ct',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.7196432,
#         'lat': 45.4293576,
#         'elevation': [{'first': 0.0, 'second': 183.22284458479427},
#          {'first': 10.0, 'second': 184.24284458479428},
#          {'first': 20.0, 'second': 185.00284458479427},
#          {'first': 34.67, 'second': 185.28284458479428},
#          {'first': 34.67, 'second': 185.28284458479428},
#          {'first': 44.72, 'second': 185.5528445847943}]},
#        {'distance': 3.798,
#         'relativeDirection': 'LEFT',
#         'streetName': 'Da Vinci',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.7191071,
#         'lat': 45.4292541,
#         'elevation': [{'first': 0.0, 'second': 185.5528445847943},
#          {'first': 3.8, 'second': 185.90284458479428}]},
#        {'distance': 388.26,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'path',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.7190945,
#         'lat': 45.4292871,
#         'elevation': [{'first': 0.0, 'second': 185.90284458479428},
#          {'first': 10.02, 'second': 186.9228445847943},
#          {'first': 10.02, 'second': 186.9228445847943},
#          {'first': 20.02, 'second': 186.84284458479428},
#          {'first': 30.02, 'second': 186.7028445847943},
#          {'first': 40.019999999999996, 'second': 186.2928445847943},
#          {'first': 50.019999999999996, 'second': 185.7928445847943},
#          {'first': 60.019999999999996, 'second': 185.68284458479428},
#          {'first': 70.02, 'second': 185.3628445847943},
#          {'first': 80.02, 'second': 184.9828445847943},
#          {'first': 90.02, 'second': 185.7328445847943},
#          {'first': 100.02, 'second': 187.19284458479427},
#          {'first': 110.02, 'second': 188.78284458479428},
#          {'first': 120.02, 'second': 190.3628445847943},
#          {'first': 130.02, 'second': 192.1728445847943},
#          {'first': 136.36, 'second': 193.06284458479428},
#          {'first': 136.392, 'second': 193.06284458479428},
#          {'first': 146.392, 'second': 193.66284458479427},
#          {'first': 156.392, 'second': 194.24284458479428},
#          {'first': 166.392, 'second': 194.72284458479427},
#          {'first': 176.392, 'second': 194.5828445847943},
#          {'first': 186.392, 'second': 193.78284458479428},
#          {'first': 196.392, 'second': 192.81284458479428},
#          {'first': 206.392, 'second': 192.4528445847943},
#          {'first': 216.392, 'second': 192.0828445847943},
#          {'first': 226.392, 'second': 191.4528445847943},
#          {'first': 236.392, 'second': 191.5528445847943},
#          {'first': 246.392, 'second': 190.87284458479428},
#          {'first': 256.392, 'second': 190.16284458479427},
#          {'first': 266.392, 'second': 189.90284458479428},
#          {'first': 276.392, 'second': 189.4528445847943},
#          {'first': 286.392, 'second': 189.21284458479428},
#          {'first': 296.392, 'second': 188.75284458479427},
#          {'first': 306.392, 'second': 187.8928445847943},
#          {'first': 316.392, 'second': 187.5428445847943},
#          {'first': 326.392, 'second': 187.6328445847943},
#          {'first': 336.392, 'second': 187.56284458479428},
#          {'first': 346.392, 'second': 187.69284458479427},
#          {'first': 356.392, 'second': 187.59284458479428},
#          {'first': 366.392, 'second': 187.7028445847943},
#          {'first': 376.392, 'second': 187.47284458479427},
#          {'first': 384.37199999999996, 'second': 186.9828445847943},
#          {'first': 384.431, 'second': 186.9828445847943},
#          {'first': 388.26099999999997, 'second': 186.65284458479428}]},
#        {'distance': 8.33,
#         'relativeDirection': 'LEFT',
#         'streetName': 'path',
#         'absoluteDirection': 'NORTHEAST',
#         'stayOn': True,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.715193,
#         'lat': 45.4280407,
#         'elevation': [{'first': 0.0, 'second': 186.65284458479428},
#          {'first': 8.33, 'second': 186.8228445847943}]},
#        {'distance': 30.315,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'Kerr Pkwy',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.715126,
#         'lat': 45.4280953,
#         'elevation': [{'first': 0.0, 'second': 186.8228445847943},
#          {'first': 11.3, 'second': 186.41284458479427},
#          {'first': 11.301, 'second': 186.41284458479427},
#          {'first': 17.361, 'second': 186.12284458479428},
#          {'first': 17.364, 'second': 186.12284458479428},
#          {'first': 27.694000000000003, 'second': 185.81284458479428}]}]},
#      {'startTime': 1683315134000,
#       'endTime': 1683318180000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': True,
#       'distance': 18663.71158321588,
#       'pathway': False,
#       'mode': 'BUS',
#       'route': '78',
#       'agencyName': 'TriMet',
#       'agencyUrl': 'https://trimet.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeType': 3,
#       'routeId': 'TriMet:78',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '7868',
#       'headsign': 'Beaverton TC',
#       'agencyId': 'TRIMET',
#       'tripId': 'TriMet:12346165',
#       'serviceDate': '20230505',
#       'from': {'name': 'Kerr & Touchstone',
#        'stopId': 'TriMet:10305',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '10305',
#        'lon': -122.714739,
#        'lat': 45.42813,
#        'arrival': 1683315133000,
#        'departure': 1683315134000,
#        'zoneId': 'B',
#        'stopIndex': 16,
#        'stopSequence': 17,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'Beaverton Transit Center',
#        'stopId': 'TriMet:9985',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9985',
#        'lon': -122.801308,
#        'lat': 45.491385,
#        'arrival': 1683318180000,
#        'departure': 1683318180000,
#        'zoneId': 'B',
#        'stopIndex': 68,
#        'stopSequence': 70,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'ktgtGdv~kV?FCXALIJCLCLEJIVAREHINKNW`@MTILSZa@p@i@x@[f@UZONOLOLOLMFWLOHgBz@SJOHOLSNE@OPKNIFGHKPYd@}@xAORKLMLKHMFKFMDMBO@M@Q?IAKASCSGKCa@KQG[GOCIAKAI?K?G?G@G@KBSF]L_@LWH{@X]J[LcAZs@XKFIDMLOROZGLK`@EVEd@K~BEdA_@tIGdACf@Kz@Kl@Mn@Oj@Sl@Wn@Sb@[f@MRa@f@OL_@^a@Xa@Ta@NUJQDg@JYDY@o@C_@?m@@u@?O?Gh@?H?T?TBPDLh@nAH\\NKf@YN@B?DBBFBJFTLj@Lj@Lh@TdALj@Lh@Lh@Jb@@@B@B?XQ\\S|@i@BE?E@C?EAGESMi@Mi@Mk@UeAMi@GUESCGO_@IMCGCMEY_@F[JYJ]PK@YNIDa@TQHcAn@KJADADCTI\\ITAFMVMTONIJQLUJSFIBM@c@?S@UDIBGDIHKJIJIRI^CXAX?bD?jM?nA?N?J?^@R@LDXF`@DNFRJTf@`Ad@~@JVHRFVF^BX@\\?|CAfB?`@CTCPKh@ITLNHJHNNZHRDLDJh@xAt@fBd@nATj@Vh@FNFFDHFHDFFDFFFDFDHDHBHDJBLBH@N@N?`@@H?^?nA?j@?v@?t@AD?L?A`L?z@?NAdEAnF@l@BhAH@H@JDPJDBR
#        {'points': 'ksgtGpiglVGRAB_AdDk@nB]jAg@fBOh@ITW~@K^Od@i@jBm@tBMb@',
#         'length': 15},
#        {'points': '{~gtG~fhlVGVA@CJq@bCCJAF?F?\\v@AL?\\ALBNBBBLJJJBB^f@FJHJ^h@p@|@h@v@JNJHMPs@bA',
#         'length': 28},
#        {'points': 'ywgtGvyhlVg@v@GHOT}AbCi@z@KR[d@_@l@KNMREHILEDGJc@p@o@bATPHDNFJ@HALIDG@A',
#         'length': 25},
#        {'points': 'yahtGflilVFKPWDQ@I@KAKISWa@GJc@p@o@bAOVW`@y@pAILUc@c@u@KUGMS]Ua@GOOYUc@]m@',
#         'length': 26},
#        {'points': 'enhtGzfilVCEEKIOEUSa@K]G[EYE]Cg@AICQEOEGMKQGKCK?G@GBKVI]m@}Ba@_Be@iBU{@ESGSYLQ@w@D[FSBG@MBUDYDI@[D',
#         'length': 40},
#        {'points': 'aaitGjqhlVSDg@H}@LSBi@FU?]@g@?e@?i@?q@?aD?k@@',
#         'length': 14},
#        {'points': 'etitGxrhlVU?eAAyC?iA?Y?aA?oA?kAAg@BQ@S@s@DYBWDM@KB]D',
#         'length': 18},
#        {'points': 'imjtGxshlVKB[B[DY@Y?_A@mA?m@?g@?', 'length': 10},
#        {'points': 'exjtGjthlVi@?SAU?cA?kCAsB?[?', 'length': 8},
#        {'points': 'yektGfthlVE?w@?MAS@}@AU?U?a@AWCWGMCMGOGe@UQKYOc@YUOWQMI',
#         'length': 21},
#        {'points': 'suktGjohlVmAy@QKMEKCQEK?KAW@UFKFKFKHMNKNCD', 'length': 16},
#        {'points': 'g~ktG|nhlVEJIPELSl@Sn@m@xB]lAGV', 'length': 9},
#        {'points': 'ybltGfzhlVITMj@u@tDYtA', 'length': 5},
#        {'points': 'afltGtdilVERu@pDe@`Ci@hCK^', 'length': 6},
#        {'points': 'yjltGftilVaA`EWhAe@lBGVs@vCQx@', 'length': 7},
#        {'points': 'gqltGjgjlVK^Kd@G\\]|AOn@Kb@WfAEPg@|BTJHDJ@F@p@@x@?`@@V?@bB',
#         'length': 19},
#        {'points': 'koltGvzjlV?H?|A?f@@f@?f@?f@?h@?f@?PvBALCF@DBBJ?FCJADGDI@GEOGK?[?_@?',
#         'length': 25},
#        {'points': 'inltGbgklVS?K?A^Ah@Af@AHA^C^?PAp@AJAHCHGLMNMNMNQQIEmBQ]CU?s@@y@?',
#         'length': 25},
#        {'points': '_{ltGtpklVi@?IIO@S?OHw@AK?EAECIGSSOVKTKRITKV[|@Sj@s@tB[z@',
#         'length': 21},
#        {'points': 'sgmtG~{klVCHM\\WKaAc@g@Uq@YSI', 'length': 8},
#        {'points': 'mnmtG|yklVECmB{@}@a@_Bu@uDaBm@Wg@U', 'length': 8},
#        {'points': 'k_ntGtpklVA?q@[y@_@eEgBMG', 'length': 6},
#        {'points': 'mintGhkklVo@U[MyAm@_@OcAa@eAe@', 'length': 7},
#        {'points': '}sntG~eklVaCiAECEAsAo@EA', 'length': 6},
#        {'points': 'e{ntG|aklVCAiDyAqB{@uB{@{Ak@MGOGw@[ME', 'length': 10},
#        {'points': '{motGjxjlViAe@}@]}@_@}@]MGCZ?n@@nB?f@@lA@p@?X@~@?z@?bA?jA?l@AnB?@',
#         'length': 20},
#        {'points': 'kvotGjmklV?fA?vAAjBAlC?r@?v@AzF?R?dB?p@?Z?rAAn@?n@?tB?^?lCDrD?rB?n@@zB?zA?d@?DET?J?PDP?F',
#         'length': 30},
#        {'points': 'kvotGvomlV?@?fA@~@?J?`@?V?J?n@@tE?|C@|@?V', 'length': 13},
#        {'points': 'evotGlfnlV?b@?v@?VAhB?fA@dA?`A@n@@dA@t@BhB?pC@fA?pB?Z?lA@zAaCA',
#         'length': 19},
#        {'points': 'yyotG`molVe@?cC?qC?eF@Y?iC?_A?', 'length': 8},
#        {'points': '_rptGbmolVkA?e@@C?sA?u@?S?_A?I?g@?e@?g@?}@?U?qA?K?',
#         'length': 16},
#        {'points': 'efqtGdmolVY?mA?iA?uB?', 'length': 5},
#        {'points': 'moqtGdmolVQ?s@?mA?aA?]?aA?oA?', 'length': 8},
#        {'points': 's{qtGdmolVI?w@A_E?A?m@?K?uB?g@?', 'length': 9},
#        {'points': 'ojrtGbmolVW?mB?C?U@w@AK?cA?e@?yA?', 'length': 10},
#        {'points': 'wwrtGbmolV]?sA?Q?YAS?c@?I?MI}@?OHS?A?c@@W?I?MBOBUHKFQJ_Al@MJC@',
#         'length': 24},
#        {'points': 'sistGdpolV]TONS@{@Tc@J]FYD]Ds@JI@gARMNa@NWLGDIDIFKJQk@AECEEGIEUUc@a@s@o@KKKSk@e@GEI?K@IDIFIJAL?HBL\\ZVTBB',
#         'length': 42}],
#       'alerts': [{'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'No service to the westbound stop at SW Hall & Scholls Ferry (Stop ID 2295) due to a ODOT ADA sidewalk project.',
#         'effectiveStartDate': 1675164600000},
#        {'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'No service to the westbound stop at SW Hall & Greenburg (Stop ID 12402) due to long-term construction. Use temp stop approx. 350 feet east of the current stop.',
#         'effectiveStartDate': 1675962427000},
#        {'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'No service to the southbound stop at 8600 Block SW Scholls Ferry (Stop ID 5161) due to construction.',
#         'effectiveStartDate': 1683047041000},
#        {'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'For trips to Beaverton Transit Center, no service at SW Main & Scoffins (Stop ID 3655) due to construction. And for trips to Lake Oswego Transit Center, no service at SW Main & Scoffins (Stop ID 3673).',
#         'effectiveStartDate': 1680887474000},
#        {'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'No service to the eastbound stop at SW Hall & Greenburg (Stop ID 2282) due to ADA sidewalk construction. Use the temporary stop on the utility pole 100 feet east.',
#         'effectiveStartDate': 1675769400000}],
#       'routeShortName': '78',
#       'routeLongName': 'Denney/Kerr Pkwy',
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 3046.0,
#       'transitLeg': True,
#       'steps': []},
#      {'startTime': 1683318180000,
#       'endTime': 1683318239000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 75.367,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Beaverton Transit Center',
#        'stopId': 'TriMet:9985',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9985',
#        'lon': -122.801308,
#        'lat': 45.491385,
#        'arrival': 1683318180000,
#        'departure': 1683318180000,
#        'zoneId': 'B',
#        'stopIndex': 68,
#        'stopSequence': 70,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'Beaverton TC MAX Station',
#        'stopId': 'TriMet:9818',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9818',
#        'lon': -122.801723,
#        'lat': 45.49133,
#        'arrival': 1683318239000,
#        'departure': 1683319065000,
#        'zoneId': 'R',
#        'stopIndex': 13,
#        'stopSequence': 14,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'c`ttGbsolVDBPRHBBBCDBBHJIPCHEFCFCHKKBEAA',
#        'length': 16},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 59.0,
#       'transitLeg': False,
#       'steps': [{'distance': 24.181,
#         'relativeDirection': 'DEPART',
#         'streetName': 'platform',
#         'absoluteDirection': 'SOUTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.80129699267805,
#         'lat': 45.49138202871433,
#         'elevation': [{'first': 3.125, 'second': 52.53284458479429},
#          {'first': 16.155, 'second': 52.6028445847943},
#          {'first': 16.154, 'second': 52.6028445847943},
#          {'first': 21.844, 'second': 52.59284458479429},
#          {'first': 21.846, 'second': 52.59284458479429},
#          {'first': 24.186, 'second': 52.5828445847943}]},
#        {'distance': 3.095,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'sidewalk',
#         'absoluteDirection': 'NORTHWEST',
#         'stayOn': True,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.8014544,
#         'lat': 45.4911979,
#         'elevation': [{'first': 0.0, 'second': 52.5828445847943},
#          {'first': 3.1, 'second': 52.6128445847943}]},
#        {'distance': 9.687999999999999,
#         'relativeDirection': 'LEFT',
#         'streetName': 'Beaverton TC (path)',
#         'absoluteDirection': 'SOUTHWEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.8014869,
#         'lat': 45.4912139,
#         'elevation': [{'first': 0.0, 'second': 52.6128445847943},
#          {'first': 2.2, 'second': 52.6328445847943},
#          {'first': 2.199, 'second': 52.6328445847943},
#          {'first': 9.689, 'second': 52.6028445847943}]},
#        {'distance': 26.657,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'Beaverton TC (path)',
#         'absoluteDirection': 'NORTHWEST',
#         'stayOn': True,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.8015611,
#         'lat': 45.491144,
#         'elevation': [{'first': 0.0, 'second': 52.6028445847943},
#          {'first': 13.66, 'second': 52.7428445847943},
#          {'first': 13.664, 'second': 52.7428445847943},
#          {'first': 26.654, 'second': 52.652844584794295}]},
#        {'distance': 11.746,
#         'relativeDirection': 'UTURN_RIGHT',
#         'streetName': 'Beaverton TC',
#         'absoluteDirection': 'SOUTHEAST',
#         'stayOn': True,
#         'area': True,
#         'bogusName': False,
#         'lon': -122.8017751,
#         'lat': 45.491343,
#         'elevation': []}]},
#      {'startTime': 1683319065000,
#       'endTime': 1683320510000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 14530.063823451408,
#       'pathway': False,
#       'mode': 'TRAM',
#       'route': 'MAX Blue Line',
#       'agencyName': 'TriMet',
#       'agencyUrl': 'https://trimet.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeColor': '084C8D',
#       'routeType': 0,
#       'routeId': 'TriMet:100',
#       'routeTextColor': 'FFFFFF',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '9027',
#       'headsign': 'Hillsboro',
#       'agencyId': 'TRIMET',
#       'tripId': 'TriMet:12350052',
#       'serviceDate': '20230505',
#       'from': {'name': 'Beaverton TC MAX Station',
#        'stopId': 'TriMet:9818',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9818',
#        'lon': -122.801723,
#        'lat': 45.49133,
#        'arrival': 1683318239000,
#        'departure': 1683319065000,
#        'zoneId': 'R',
#        'stopIndex': 13,
#        'stopSequence': 14,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'Washington/SE 12th Ave MAX Station',
#        'stopId': 'TriMet:9842',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9842',
#        'lon': -122.969867,
#        'lat': 45.521231,
#        'arrival': 1683320510000,
#        'departure': 1683320511000,
#        'zoneId': 'R',
#        'stopIndex': 24,
#        'stopSequence': 25,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 
#         'length': 25},
#        {'points': 'ywvtG`twlVADEHEHKVELWl@Sj@iAxCYr@Yp@u@jBUf@Sf@Uh@Q`@O`@q@|A_DtHiBnEs@fBs@fB]z@i@rASf@ITaAdC',
#         'length': 27},
#        {'points': 'guwtGlnylVSh@IRKVm@xAcDnIs@fBs@fBIVg@lAcAhCUl@sAhDUl@Sj@Ut@Of@Ql@Ol@IXMh@YpA{@vDc@lByBzJQv@c@lBsAdGMj@Mh@Mf@Qv@[vAOj@Mj@K`@I^K\\EPERa@zAk@|BELGVKd@On@GRKd@q@zC',
#         'length': 49},
#        {'points': 'ubytGtc}lVGXu@dDi@~Bg@`C}@zD{CbN}AdHaCtKaAjE_AbEeAvEa@lB_@hBe@`CYtAG\\]|A_CjKERI\\GTsAbG',
#         'length': 23},
#        {'points': '{gztG~w`mVGVc@rBQv@Qv@a@pBa@rBc@pBcBpHk@hCoAvFmArFoAtF{@zDSz@gB`IYpAy@pDaAlEcApEWhAo@xCWhAo@tCyA|GSbAS`AOr@Kl@Kp@Kp@Kr@Gj@Kv@Gh@KhAIfAEb@Cb@Gx@Cf@Cp@Ad@EfAAt@AfAAdAA~@@`A?Z?R?R?xA?fD',
#         'length': 54},
#        {'points': 'os{tGfafmV?jC?xB@lA?tABlD@rB?dB@fN?dB@jA?zA?dB?f@?p@?|I@dE@jD@bA?^@R@X@VBb@Bb@BZBZB\\^bD?D',
#         'length': 30},
#        {'points': 'cq{tGp~hmVF`@BVBZRhBRjBRbBf@zDTjBn@pF\\zCNrANvAFr@ZxDVzCD`@LjAj@bFx@lHNnANlAVlBd@jDf@hDb@dD',
#         'length': 26},
#        {'points': 'k~ztGt~kmVDXL~@LlAfBrO`@rDb@nDr@nGHj@Jv@DVDVF^FXHb@Jj@Lf@Lf@Lf@Lb@X|@Pb@Zz@rElLdErKb@lARh@N`@Tv@Rt@Pn@VhABLLn@Nx@h@vCTjARjAHl@BZBXBZB^@Z@\\?^?~@@hH?\\AX?ZAd@ItBAn@OfE',
#         'length': 55}],
#       'alerts': [{'alertUrl': 'https://trimet.org/improvements',
#         'alertDescriptionText': 'Through end of service Saturday, May 6, MAX Blue, Green, and Red lines are disrupted between Gateway Transit Center and NE 7th Ave MAX stations. The disruption is part of our "A Better Red" project. Shuttle buses are serving stations in both directions between Gateway TC and NE 7th Ave. Expect delays. For more info, visit: trimet.org/improvements',
#         'effectiveStartDate': 1681642800000},
#        {'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'The southeast parking garage elevator at Gateway Transit Center is out of service. Please use southwest corner elevator. More: trimet.org/elevator',
#         'effectiveStartDate': 1682683767000}],
#       'routeLongName': 'MAX Blue Line',
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 1445.0,
#       'transitLeg': True,
#       'steps': []},
#      {'startTime': 1683320511000,
#       'endTime': 1683321221000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 903.3450000000001,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Washington/SE 12th Ave MAX Station',
#        'stopId': 'TriMet:9842',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9842',
#        'lon': -122.969867,
#        'lat': 45.521231,
#        'arrival': 1683320510000,
#        'departure': 1683320511000,
#        'zoneId': 'R',
#        'stopIndex': 24,
#        'stopSequence': 25,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'Destination',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.969953,
#        'lat': 45.525905,
#        'arrival': 1683321221000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'legGeometry': {'points': 'uzytGtppmV?DC?APC@UCQBK@I?A?A@CDE?EAEECACFCCM[BmA@QNwE@c@??By@@SwFASt@In@G~B}BDYFONM\\El@@zCgA?oA@[?S?KBMFIHWh@GIC?CAAAY]w@s@KG',
#        'length': 51},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 710.0,
#       'transitLeg': False,
#       'steps': [{'distance': 3.6470000000000002,
#         'relativeDirection': 'DEPART',
#         'streetName': 'Washington/SE 12th Ave',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.96986605736964,
#         'lat': 45.521237045327496,
#         'elevation': []},
#        {'distance': 7.617,
#         'relativeDirection': 'LEFT',
#         'streetName': 'path',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.9698907,
#         'lat': 45.5212529,
#         'elevation': [{'first': 0.0, 'second': 53.00284458479429},
#          {'first': 7.62, 'second': 53.00284458479429}]},
#        {'distance': 76.95400000000001,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'SE 12th Ave (path)',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9699879,
#         'lat': 45.5212603,
#         'elevation': [{'first': 0.0, 'second': 53.00284458479429},
#          {'first': 2.94, 'second': 52.92284458479429},
#          {'first': 2.94, 'second': 52.92284458479429},
#          {'first': 12.94, 'second': 53.0228445847943},
#          {'first': 22.94, 'second': 53.012844584794294},
#          {'first': 32.94, 'second': 52.652844584794295},
#          {'first': 42.94, 'second': 52.432844584794296},
#          {'first': 54.4, 'second': 52.45284458479429},
#          {'first': 60.698, 'second': 52.45284458479429},
#          {'first': 62.938, 'second': 52.402844584794295},
#          {'first': 62.933, 'second': 52.402844584794295},
#          {'first': 67.003, 'second': 52.3028445847943}]},
#        {'distance': 166.447,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'E Main St',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9698712,
#         'lat': 45.5218599,
#         'elevation': [{'first': 0.0, 'second': 52.1928445847943},
#          {'first': 10.0, 'second': 52.2428445847943},
#          {'first': 20.0, 'second': 52.402844584794295},
#          {'first': 30.5, 'second': 52.48284458479429},
#          {'first': 30.495, 'second': 52.48284458479429},
#          {'first': 37.105000000000004, 'second': 52.512844584794294},
#          {'first': 37.105000000000004, 'second': 52.512844584794294},
#          {'first': 47.105000000000004, 'second': 52.59284458479429},
#          {'first': 57.105000000000004, 'second': 52.6928445847943},
#          {'first': 67.105, 'second': 52.872844584794294},
#          {'first': 77.105, 'second': 53.09284458479429},
#          {'first': 87.105, 'second': 53.25284458479429},
#          {'first': 97.105, 'second': 53.402844584794295},
#          {'first': 107.105, 'second': 53.50284458479429},
#          {'first': 121.915, 'second': 53.6128445847943},
#          {'first': 158.64000000000001, 'second': 53.95284458479429},
#          {'first': 166.45000000000002, 'second': 54.0528445847943}]},
#        {'distance': 137.728,
#         'relativeDirection': 'LEFT',
#         'streetName': 'NE 14th Ave',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9677458,
#         'lat': 45.5217076,
#         'elevation': [{'first': 0.0, 'second': 54.0528445847943},
#          {'first': 10.0, 'second': 54.03284458479429},
#          {'first': 20.0, 'second': 53.8628445847943},
#          {'first': 30.0, 'second': 53.762844584794294},
#          {'first': 40.0, 'second': 53.7428445847943},
#          {'first': 50.0, 'second': 53.7428445847943},
#          {'first': 60.0, 'second': 53.682844584794296},
#          {'first': 70.0, 'second': 53.59284458479429},
#          {'first': 80.0, 'second': 53.56284458479429},
#          {'first': 90.0, 'second': 53.4628445847943},
#          {'first': 100.0, 'second': 53.262844584794294},
#          {'first': 110.0, 'second': 53.1328445847943},
#          {'first': 120.0, 'second': 53.0528445847943},
#          {'first': 130.0, 'second': 52.8028445847943},
#          {'first': 137.73, 'second': 52.7428445847943}]},
#        {'distance': 93.298,
#         'relativeDirection': 'LEFT',
#         'streetName': 'NE Lincoln St',
#         'absoluteDirection': 'NORTHWEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9677357,
#         'lat': 45.5229462,
#         'elevation': [{'first': 0.0, 'second': 52.7428445847943},
#          {'first': 10.0, 'second': 52.792844584794295},
#          {'first': 20.0, 'second': 52.9628445847943},
#          {'first': 30.0, 'second': 53.0528445847943},
#          {'first': 40.0, 'second': 53.1328445847943},
#          {'first': 50.0, 'second': 53.23284458479429},
#          {'first': 60.0, 'second': 53.3028445847943},
#          {'first': 70.0, 'second': 53.3528445847943},
#          {'first': 80.0, 'second': 53.3628445847943},
#          {'first': 93.29, 'second': 53.2728445847943}]},
#        {'distance': 188.659,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE Lincoln St',
#         'absoluteDirection': 'NORTH',
#         'stayOn': True,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9688856,
#         'lat': 45.523135,
#         'elevation': [{'first': 0.0, 'second': 53.2728445847943},
#          {'first': 10.0, 'second': 53.28284458479429},
#          {'first': 20.0, 'second': 53.3028445847943},
#          {'first': 30.0, 'second': 53.182844584794296},
#          {'first': 40.0, 'second': 53.042844584794295},
#          {'first': 50.0, 'second': 52.7728445847943},
#          {'first': 60.0, 'second': 52.4128445847943},
#          {'first': 70.0, 'second': 51.98284458479429},
#          {'first': 80.0, 'second': 51.59284458479429},
#          {'first': 90.0, 'second': 51.3028445847943},
#          {'first': 100.0, 'second': 51.2128445847943},
#          {'first': 110.0, 'second': 51.4928445847943},
#          {'first': 120.0, 'second': 51.8028445847943},
#          {'first': 130.0, 'second': 51.9128445847943},
#          {'first': 140.0, 'second': 52.4428445847943},
#          {'first': 150.0, 'second': 52.81284458479429},
#          {'first': 160.0, 'second': 52.8528445847943},
#          {'first': 170.0, 'second': 52.9128445847943},
#          {'first': 180.0, 'second': 53.00284458479429},
#          {'first': 188.71, 'second': 53.0228445847943}]},
#        {'distance': 154.413,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE 12th Ave',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.970199,
#         'lat': 45.5240647,
#         'elevation': [{'first': 0.0, 'second': 53.0228445847943},
#          {'first': 10.0, 'second': 52.902844584794295},
#          {'first': 20.0, 'second': 52.8328445847943},
#          {'first': 30.0, 'second': 52.70284458479429},
#          {'first': 39.8, 'second': 52.512844584794294},
#          {'first': 39.796, 'second': 52.512844584794294},
#          {'first': 49.796, 'second': 52.2728445847943},
#          {'first': 59.796, 'second': 51.9128445847943},
#          {'first': 69.79599999999999, 'second': 51.56284458479429},
#          {'first': 84.226, 'second': 51.1028445847943},
#          {'first': 84.22200000000001, 'second': 51.1028445847943},
#          {'first': 94.22200000000001, 'second': 50.652844584794295},
#          {'first': 99.93200000000002, 'second': 50.4628445847943},
#          {'first': 99.933, 'second': 50.4628445847943},
#          {'first': 109.933, 'second': 50.1628445847943},
#          {'first': 119.933, 'second': 49.8928445847943},
#          {'first': 129.933, 'second': 49.652844584794295},
#          {'first': 139.933, 'second': 49.582844584794294},
#          {'first': 154.413, 'second': 49.722844584794295}]},
#        {'distance': 74.582,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'path',
#         'absoluteDirection': 'NORTHEAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.9705252,
#         'lat': 45.525369,
#         'elevation': [{'first': 0.0, 'second': 49.722844584794295},
#          {'first': 6.21, 'second': 49.872844584794294}]}]}],
#     'tooSloped': False},
#    {'duration': 7184,
#     'startTime': 1683314480000,
#     'endTime': 1683321664000,
#     'walkTime': 1409,
#     'transitTime': 5129,
#     'waitingTime': 646,
#     'walkDistance': 1737.166552228479,
#     'walkLimitExceeded': False,
#     'elevationLost': 18.590000000000014,
#     'elevationGained': 23.360000000000017,
#     'transfers': 1,
#     'fare': {'fare': {'regular': {'currency': {'symbol': '$',
#         'currency': 'USD',
#         'defaultFractionDigits': 2,
#         'currencyCode': 'USD'},
#        'cents': 250}},
#      'details': {'regular': []}},
#     'legs': [{'startTime': 1683314480000,
#       'endTime': 1683315133000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 655.756,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Origin',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.721025,
#        'lat': 45.429642,
#        'departure': 1683314480000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'to': {'name': 'Kerr & Touchstone',
#        'stopId': 'TriMet:10305',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '10305',
#        'lon': -122.714739,
#        'lat': 45.42813,
#        'arrival': 1683315133000,
#        'departure': 1683315134000,
#        'zoneId': 'B',
#        'stopIndex': 16,
#        'stopSequence': 17,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'e~gtGn}_lVMTEJIIIIGKIKGMGM`@u@DIBOBOLi@@MFQDKDGXSJMDM@AAKBI@GBK@M@O@GBA@YEABYD_@BODWRaAF[?G?E?CCCWUY]QQJYBMBW@GBG@E@E@CBELSDKHWBGLSHQBG@C@C@?@APGBCFODMFSBKBGBGBEFIRUPSTc@HOFOPq@@G?CACGE@IAQ@MBY?G',
#        'length': 90},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 653.0,
#       'transitLeg': False,
#       'steps': [{'distance': 17.487000000000002,
#         'relativeDirection': 'DEPART',
#         'streetName': 'path',
#         'absoluteDirection': 'NORTHWEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.72103143132752,
#         'lat': 45.42963664519159,
#         'elevation': [{'first': 0.0, 'second': 172.00284458479427},
#          {'first': 10.0, 'second': 173.3828445847943},
#          {'first': 11.62, 'second': 173.56284458479428},
#          {'first': 11.621, 'second': 179.15284458479428},
#          {'first': 17.491, 'second': 178.9828445847943}]},
#        {'distance': 41.36,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'Cellini Ct',
#         'absoluteDirection': 'NORTHEAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.7212013,
#         'lat': 45.4297392,
#         'elevation': [{'first': 0.0, 'second': 178.9828445847943},
#          {'first': 10.0, 'second': 180.25284458479427},
#          {'first': 20.0, 'second': 181.52284458479429},
#          {'first': 30.0, 'second': 182.77284458479429},
#          {'first': 41.37, 'second': 183.5128445847943}]},
#        {'distance': 121.489,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'Cellini',
#         'absoluteDirection': 'SOUTHEAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.7208406,
#         'lat': 45.4300097,
#         'elevation': [{'first': 0.0, 'second': 183.5128445847943},
#          {'first': 10.0, 'second': 183.5128445847943},
#          {'first': 20.0, 'second': 183.22284458479427},
#          {'first': 30.0, 'second': 182.78284458479428},
#          {'first': 40.0, 'second': 182.1428445847943},
#          {'first': 50.0, 'second': 181.8028445847943},
#          {'first': 60.0, 'second': 181.3828445847943},
#          {'first': 70.0, 'second': 180.99284458479428},
#          {'first': 80.0, 'second': 181.1728445847943},
#          {'first': 90.0, 'second': 181.4528445847943},
#          {'first': 100.0, 'second': 181.75284458479427},
#          {'first': 110.0, 'second': 182.34284458479428},
#          {'first': 120.24, 'second': 183.09284458479428},
#          {'first': 120.238, 'second': 183.09284458479428},
#          {'first': 121.488, 'second': 183.22284458479427}]},
#        {'distance': 44.717,
#         'relativeDirection': 'SLIGHTLY_LEFT',
#         'streetName': 'Cellini Ct',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.

#         'streetName': 'path',
#         'absoluteDirection': 'NORTHEAST',
#         'stayOn': True,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.715193,
#         'lat': 45.4280407,
#         'elevation': [{'first': 0.0, 'second': 186.65284458479428},
#          {'first': 8.33, 'second': 186.8228445847943}]},
#        {'distance': 30.315,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'Kerr Pkwy',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.715126,
#         'lat': 45.4280953,
# ...
#         'stayOn': True,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.8015611,
#         'lat': 45.491144,
#         'elevation': [{'first': 0.0, 'second': 52.6028445847943},
#          {'first': 13.66, 'second': 52.7428445847943},
#          {'first': 13.664, 'second': 52.7428445847943},
#          {'first': 26.654, 'second': 52.652844584794295}]},
#        {'distance': 11.746,
#         'relativeDirection': 'UTURN_RIGHT',
#         'streetName': 'Beaverton TC',
#         'absoluteDirection': 'SOUTHEAST',
#         'stayOn': True,
#         'area': True,
#         'bogusName': False,
#         'lon': -122.8017751,
#         'lat': 45.491343,
#         'elevation': []}]},
#      {'startTime': 1683319965000,
#       'endTime': 1683321410000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 14530.063823451408,
#       'pathway': False,
#       'mode': 'TRAM',
#       'route': 'MAX Blue Line',
#       'agencyName': 'TriMet',
#       'agencyUrl': 'https://trimet.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeColor': '084C8D',
#       'routeType': 0,
#       'routeId': 'TriMet:100',
#       'routeTextColor': 'FFFFFF',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '9024',
#       'headsign': 'Hillsboro',
#       'agencyId': 'TRIMET',
#       'tripId': 'TriMet:12350054',
#       'serviceDate': '20230505',
#       'from': {'name': 'Beaverton TC MAX Station',
#        'stopId': 'TriMet:9818',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9818',
#        'lon': -122.801723,
#        'lat': 45.49133,
#        'arrival': 1683318239000,
#        'departure': 1683319965000,
#        'zoneId': 'R',
#        'stopIndex': 13,
#        'stopSequence': 14,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'Washington/SE 12th Ave MAX Station',
#        'stopId': 'TriMet:9842',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9842',
#        'lon': -122.969867,
#        'lat': 45.521231,
#        'arrival': 1683321410000,
#        'departure': 1683321411000,
#        'zoneId': 'R',
#        'stopIndex': 24,
#        'stopSequence': 25,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'w_ttGtuolVLLJNHHDHFJFJBLFPBLBH@JBN?F@J@`@D~ABn@@l@?V?NArB?vA?Z?V@X?P@ZBZBXB^BNBRDZHb@l@|D?@H`@N`ADT@TBR?R@TARARARCPCPCNCJELEP{AdFYdASl@qB~GgCpIIXGVKXqAlE_BfFgIrXGTOf@y@pCIXo@vBuAvEENcBvFgDdLy@rCe@vASj@Sh@Sh@Sf@kArC[t@Wn@KRUj@a@~@a@z@aAvBOZMX]x@yAnDa@`Aa@~@]~@_AdCUj@_A`CMXw@hBcAbCyAnDWj@Yn@[r@_@r@oBvDWh@MTIRUf@OZc@bAo@|A_@|@}@vBADEHEHKVELWl@Sj@iAxCYr@Yp@u@jBUf@Sf@Uh@Q`@O`@q@|A_DtHiBnEs@fBs@fB]z@i@rASf@ITaAdCSh@IRKVm@xAcDnIs@fBs@fBIVg@lAcAhCUl@sAhDUl@Sj@Ut@Of@Ql@Ol@IXMh@YpA{@vDc@lByBzJQv@c@lBsAdGMj@Mh@Mf@Qv@[vAOj@Mj@K`@I^K\\EPERa@zAk@|BELGVKd@On@GRKd@q@zCGXu@dDi@~Bg@`C}@zD
#         'length': 54},
#        {'points': 'os{tGfafmV?jC?xB@lA?tABlD@rB?dB@fN?dB@jA?zA?dB?f@?p@?|I@dE@jD@bA?^@R@X@VBb@Bb@BZBZB\\^bD?D',
#         'length': 30},
#        {'points': 'cq{tGp~hmVF`@BVBZRhBRjBRbBf@zDTjBn@pF\\zCNrANvAFr@ZxDVzCD`@LjAj@bFx@lHNnANlAVlBd@jDf@hDb@dD',
#         'length': 26},
#        {'points': 'k~ztGt~kmVDXL~@LlAfBrO`@rDb@nDr@nGHj@Jv@DVDVF^FXHb@Jj@Lf@Lf@Lf@Lb@X|@Pb@Zz@rElLdErKb@lARh@N`@Tv@Rt@Pn@VhABLLn@Nx@h@vCTjARjAHl@BZBXBZB^@Z@\\?^?~@@hH?\\AX?ZAd@ItBAn@OfE',
#         'length': 55}],
#       'alerts': [{'alertUrl': 'https://trimet.org/improvements',
#         'alertDescriptionText': 'Through end of service Saturday, May 6, MAX Blue, Green, and Red lines are disrupted between Gateway Transit Center and NE 7th Ave MAX stations. The disruption is part of our "A Better Red" project. Shuttle buses are serving stations in both directions between Gateway TC and NE 7th Ave. Expect delays. For more info, visit: trimet.org/improvements',
#         'effectiveStartDate': 1681642800000},
#        {'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'The southeast parking garage elevator at Gateway Transit Center is out of service. Please use southwest corner elevator. More: trimet.org/elevator',
#         'effectiveStartDate': 1682683767000}],
#       'routeLongName': 'MAX Blue Line',
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 1445.0,
#       'transitLeg': True,
#       'steps': []},
#      {'startTime': 1683321411000,
#       'endTime': 1683322121000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 903.3450000000001,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Washington/SE 12th Ave MAX Station',
#        'stopId': 'TriMet:9842',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '9842',
#        'lon': -122.969867,
#        'lat': 45.521231,
#        'arrival': 1683321410000,
#        'departure': 1683321411000,
#        'zoneId': 'R',
#        'stopIndex': 24,
#        'stopSequence': 25,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'Destination',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.969953,
#        'lat': 45.525905,
#        'arrival': 1683322121000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'legGeometry': {'points': 'uzytGtppmV?DC?APC@UCQBK@I?A?A@CDE?EAEECACFCCM[BmA@QNwE@c@??By@@SwFASt@In@G~B}BDYFONM\\El@@zCgA?oA@[?S?KBMFIHWh@GIC?CAAAY]w@s@KG',
#        'length': 51},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 710.0,
#       'transitLeg': False,
#       'steps': [{'distance': 3.6470000000000002,
#         'relativeDirection': 'DEPART',
#         'streetName': 'Washington/SE 12th Ave',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.96986605736964,
#         'lat': 45.521237045327496,
#         'elevation': []},
#        {'distance': 7.617,
#         'relativeDirection': 'LEFT',
#         'streetName': 'path',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.9698907,
#         'lat': 45.5212529,
#         'elevation': [{'first': 0.0, 'second': 53.00284458479429},
#          {'first': 7.62, 'second': 53.00284458479429}]},
#        {'distance': 76.95400000000001,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'SE 12th Ave (path)',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9699879,
#         'lat': 45.5212603,
#         'elevation': [{'first': 0.0, 'second': 53.00284458479429},
#          {'first': 2.94, 'second': 52.92284458479429},
#          {'first': 2.94, 'second': 52.92284458479429},
#          {'first': 12.94, 'second': 53.0228445847943},
#          {'first': 22.94, 'second': 53.012844584794294},
#          {'first': 32.94, 'second': 52.652844584794295},
#          {'first': 42.94, 'second': 52.432844584794296},
#          {'first': 54.4, 'second': 52.45284458479429},
#          {'first': 60.698, 'second': 52.45284458479429},
#          {'first': 62.938, 'second': 52.402844584794295},
#          {'first': 62.933, 'second': 52.402844584794295},
#          {'first': 67.003, 'second': 52.3028445847943}]},
#        {'distance': 166.447,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'E Main St',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9698712,
#         'lat': 45.5218599,
#         'elevation': [{'first': 0.0, 'second': 52.1928445847943},
#          {'first': 10.0, 'second': 52.2428445847943},
#          {'first': 20.0, 'second': 52.402844584794295},
#          {'first': 30.5, 'second': 52.48284458479429},
#          {'first': 30.495, 'second': 52.48284458479429},
#          {'first': 37.105000000000004, 'second': 52.512844584794294},
#          {'first': 37.105000000000004, 'second': 52.512844584794294},
#          {'first': 47.105000000000004, 'second': 52.59284458479429},
#          {'first': 57.105000000000004, 'second': 52.6928445847943},
#          {'first': 67.105, 'second': 52.872844584794294},
#          {'first': 77.105, 'second': 53.09284458479429},
#          {'first': 87.105, 'second': 53.25284458479429},
#          {'first': 97.105, 'second': 53.402844584794295},
#          {'first': 107.105, 'second': 53.50284458479429},
#          {'first': 121.915, 'second': 53.6128445847943},
#          {'first': 158.64000000000001, 'second': 53.95284458479429},
#          {'first': 166.45000000000002, 'second': 54.0528445847943}]},
#        {'distance': 137.728,
#         'relativeDirection': 'LEFT',
#         'streetName': 'NE 14th Ave',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9677458,
#         'lat': 45.5217076,
#         'elevation': [{'first': 0.0, 'second': 54.0528445847943},
#          {'first': 10.0, 'second': 54.03284458479429},
#          {'first': 20.0, 'second': 53.8628445847943},
#          {'first': 30.0, 'second': 53.762844584794294},
#          {'first': 40.0, 'second': 53.7428445847943},
#          {'first': 50.0, 'second': 53.7428445847943},
#          {'first': 60.0, 'second': 53.682844584794296},
#          {'first': 70.0, 'second': 53.59284458479429},
#          {'first': 80.0, 'second': 53.56284458479429},
#          {'first': 90.0, 'second': 53.4628445847943},
#          {'first': 100.0, 'second': 53.262844584794294},
#          {'first': 110.0, 'second': 53.1328445847943},
#          {'first': 120.0, 'second': 53.0528445847943},
#          {'first': 130.0, 'second': 52.8028445847943},
#          {'first': 137.73, 'second': 52.7428445847943}]},
#        {'distance': 93.298,
#         'relativeDirection': 'LEFT',
#         'streetName': 'NE Lincoln St',
#         'absoluteDirection': 'NORTHWEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9677357,
#         'lat': 45.5229462,
#         'elevation': [{'first': 0.0, 'second': 52.7428445847943},
#          {'first': 10.0, 'second': 52.792844584794295},
#          {'first': 20.0, 'second': 52.9628445847943},
#          {'first': 30.0, 'second': 53.0528445847943},
#          {'first': 40.0, 'second': 53.1328445847943},
#          {'first': 50.0, 'second': 53.23284458479429},
#          {'first': 60.0, 'second': 53.3028445847943},
#          {'first': 70.0, 'second': 53.3528445847943},
#          {'first': 80.0, 'second': 53.3628445847943},
#          {'first': 93.29, 'second': 53.2728445847943}]},
#        {'distance': 188.659,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE Lincoln St',
#         'absoluteDirection': 'NORTH',
#         'stayOn': True,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.9688856,
#         'lat': 45.523135,
#         'elevation': [{'first': 0.0, 'second': 53.2728445847943},
#          {'first': 10.0, 'second': 53.28284458479429},
#          {'first': 20.0, 'second': 53.3028445847943},
#          {'first': 30.0, 'second': 53.182844584794296},
#          {'first': 40.0, 'second': 53.042844584794295},
#          {'first': 50.0, 'second': 52.7728445847943},
#          {'first': 60.0, 'second': 52.4128445847943},
#          {'first': 70.0, 'second': 51.98284458479429},
#          {'first': 80.0, 'second': 51.59284458479429},
#          {'first': 90.0, 'second': 51.3028445847943},
#          {'first': 100.0, 'second': 51.2128445847943},
#          {'first': 110.0, 'second': 51.4928445847943},
#          {'first': 120.0, 'second': 51.8028445847943},
#          {'first': 130.0, 'second': 51.9128445847943},
#          {'first': 140.0, 'second': 52.4428445847943},
#          {'first': 150.0, 'second': 52.81284458479429},
#          {'first': 160.0, 'second': 52.8528445847943},
#          {'first': 170.0, 'second': 52.9128445847943},
#          {'first': 180.0, 'second': 53.00284458479429},
#          {'first': 188.71, 'second': 53.0228445847943}]},
#        {'distance': 154.413,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE 12th Ave',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.970199,
#         'lat': 45.5240647,
#         'elevation': [{'first': 0.0, 'second': 53.0228445847943},
#          {'first': 10.0, 'second': 52.902844584794295},
#          {'first': 20.0, 'second': 52.8328445847943},
#          {'first': 30.0, 'second': 52.70284458479429},
#          {'first': 39.8, 'second': 52.512844584794294},
#          {'first': 39.796, 'second': 52.512844584794294},
#          {'first': 49.796, 'second': 52.2728445847943},
#          {'first': 59.796, 'second': 51.9128445847943},
#          {'first': 69.79599999999999, 'second': 51.56284458479429},
#          {'first': 84.226, 'second': 51.1028445847943},
#          {'first': 84.22200000000001, 'second': 51.1028445847943},
#          {'first': 94.22200000000001, 'second': 50.652844584794295},
#          {'first': 99.93200000000002, 'second': 50.4628445847943},
#          {'first': 99.933, 'second': 50.4628445847943},
#          {'first': 109.933, 'second': 50.1628445847943},
#          {'first': 119.933, 'second': 49.8928445847943},
#          {'first': 129.933, 'second': 49.652844584794295},
#          {'first': 139.933, 'second': 49.582844584794294},
#          {'first': 154.413, 'second': 49.722844584794295}]},
#        {'distance': 74.582,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'path',
#         'absoluteDirection': 'NORTHEAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.9705252,
#         'lat': 45.525369,
#         'elevation': [{'first': 0.0, 'second': 49.722844584794295},
#          {'first': 6.21, 'second': 49.872844584794294}]}]}],
#     'tooSloped': False}]},
#  'debugOutput': {'precalculationTime': 107,
#   'pathCalculationTime': 209,
#   'pathTimes': [70, 90, 48],
#   'renderingTime': 9,
#   'totalTime': 325,
#   'timedOut': False},
#  'elevationMetadata': {'ellipsoidToGeoidDifference': -19.522844584794296,
#   'geoidElevation': True}}

# %%
itineraries_df = get_itinerary_paths(json_content)

# %%
itineraries_df.head(2)
# Out:
#    itin_idx  totalTime  walkTime  transitTime  waitingTime  walkDistance
# 0         0       6741      1422         4491          828    1635.03703  \
# 0         0       6741      1422         4491          828    1635.03703
#
#    leg_id route_id  mode fromStopCode           fromName toStopCode
# 0       0     WALK  WALK                          Origin      10305  \
# 0       1       78   BUS        10305  Kerr & Touchstone       9985
#
#                      toName                                        legGeometry
# 0         Kerr & Touchstone  LINESTRING (-122.72104 45.42963, -122.72115 45...
# 0  Beaverton Transit Center  LINESTRING (-122.71475 45.42806, -122.71479 45...

# %%
itineraries_gdf = gpd.GeoDataFrame(itineraries_df, crs="4326", geometry="legGeometry")
itineraries_gdf.head(2)
# Out:
#    itin_idx  totalTime  walkTime  transitTime  waitingTime  walkDistance
# 0         0       6741      1422         4491          828    1635.03703  \
# 0         0       6741      1422         4491          828    1635.03703
#
#    leg_id route_id  mode fromStopCode           fromName toStopCode
# 0       0     WALK  WALK                          Origin      10305  \
# 0       1       78   BUS        10305  Kerr & Touchstone       9985
#
#                      toName                                        legGeometry
# 0         Kerr & Touchstone  LINESTRING (-122.72104 45.42963, -122.72115 45...
# 0  Beaverton Transit Center  LINESTRING (-122.71475 45.42806, -122.71479 45...

# %%
unique_combinations = itineraries_df[itineraries_df['route_id']!='WALK'].groupby('itin_idx').agg(route_id_list=('route_id',list)).reset_index().drop_duplicates(subset='route_id_list')
unique_combinations['route_id_combo'] = unique_combinations['route_id_list'].apply(lambda x: " to ".join(x))
unique_combinations
# Out:
#    itin_idx route_id_list route_id_combo
# 0         0     [78, 100]      78 to 100
# 1         1      [78, 57]       78 to 57

# %%
itineraries_reduced = itineraries_gdf.merge(unique_combinations, how='inner', on='itin_idx')
itineraries_reduced.head(3)
# Out:
#    itin_idx  totalTime  walkTime  transitTime  waitingTime  walkDistance
# 0         0       6741      1422         4491          828    1635.03703  \
# 1         0       6741      1422         4491          828    1635.03703
# 2         0       6741      1422         4491          828    1635.03703
#
#    leg_id route_id  mode fromStopCode                  fromName toStopCode
# 0       0     WALK  WALK                                 Origin      10305  \
# 1       1       78   BUS        10305         Kerr & Touchstone       9985
# 2       2     WALK  WALK         9985  Beaverton Transit Center       9818
#
#                      toName
# 0         Kerr & Touchstone  \
# 1  Beaverton Transit Center
# 2  Beaverton TC MAX Station
#
#                                          legGeometry route_id_list
# 0  LINESTRING (-122.72104 45.42963, -122.72115 45...     [78, 100]  \
# 1  LINESTRING (-122.71475 45.42806, -122.71479 45...     [78, 100]
# 2  LINESTRING (-122.80130 45.49138, -122.80132 45...     [78, 100]
#
#   route_id_combo
# 0      78 to 100
# 1      78 to 100
# 2      78 to 100

# %%
m = itineraries_reduced[itineraries_reduced['itin_idx']==0].explore(column='route_id', tiles='CartoDB positron')
gdf_points.explore(m=m, color='red')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d481a25234d6b9cab1a8aefe02f3e6e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend route_id&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;route_id&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;100&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;78&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;WALK&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d481a25234d6b9cab1a8aefe02f3e6e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d481a25234d6b9cab1a8aefe02f3e6e5 = L.map(
#                 &quot;map_d481a25234d6b9cab1a8aefe02f3e6e5&quot;,
#                 {
#                     center: [45.47791, -122.84263999999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d481a25234d6b9cab1a8aefe02f3e6e5);
#
#
#
#
#
#             var tile_layer_4a19c36f198200155bad7d2a6eb9ac62 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d481a25234d6b9cab1a8aefe02f3e6e5);
#
#
#             map_d481a25234d6b9cab1a8aefe02f3e6e5.fitBounds(
#                 [[45.42549, -122.97053], [45.53033, -122.71475]],
#                 {}
#             );
#
#
#         function geo_json_b8aace65e743d685521cf01e3c323803_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#8c564b&quot;, &quot;fillColor&quot;: &quot;#8c564b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#1f77b4&quot;, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&q

# %%
import folium
import seaborn as sns

# %%
itineraries_centroid = itineraries_reduced.unary_union.convex_hull.centroid

# %%
# Get Unique continents
color_labels = itineraries_reduced['route_id'].unique()

# List of colors in the color palettes
hex_values = sns.color_palette("Set2", len(color_labels)).as_hex()

# Map continents to the colors
color_map = dict(zip(color_labels, hex_values))

# %%
color_map['WALK']
# Out:
# '#66c2a5'

# %%
m = folium.Map(location=[itineraries_centroid.y, itineraries_centroid.x], zoom_start=13, tiles='CartoDB positron')
origin_dest_points = folium.GeoJson(gdf_points.to_json(), name='origin_destination')
origin_dest_points.add_to(m)

for idx, itin_group in itineraries_reduced.groupby('itin_idx'):
    itin_idx = itin_group.iloc[0]['itin_idx']
    itin_route_combo = itin_group.iloc[0]['route_id_combo']
    group_json = itin_group.to_json()
    folium.GeoJson(group_json, name=f'{itin_route_combo}'
                   , tooltip=folium.GeoJsonTooltip(fields=['route_id'])
                   ,style_function=lambda feature: {
                                    'color': color_map[feature['properties']['route_id']],
                                    'weight': 1
                                }
                   ).add_to(m)
folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc3650b710f28d47911187ebb45cb892 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc3650b710f28d47911187ebb45cb892&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc3650b710f28d47911187ebb45cb892 = L.map(
#                 &quot;map_dc3650b710f28d47911187ebb45cb892&quot;,
#                 {
#                     center: [45.48219771021486, -122.84657625135588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3fa58294d22ef7b67b5a657857f5359 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc3650b710f28d47911187ebb45cb892);
#
#
#
#         function geo_json_34eeb584cc863c9119481aaef1fb9ba9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_34eeb584cc863c9119481aaef1fb9ba9 = L.geoJson(null, {
#                 onEachFeature: geo_json_34eeb584cc863c9119481aaef1fb9ba9_onEachFeature,
#
#         });
#
#         function geo_json_34eeb584cc863c9119481aaef1fb9ba9_add (data) {
#             geo_json_34eeb584cc863c9119481aaef1fb9ba9
#                 .addData(data)
#                 .addTo(map_dc3650b710f28d47911187ebb45cb892);
#         }
#             geo_json_34eeb584cc863c9119481aaef1fb9ba9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.72102532885076, 45.42964247340347], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;points_str&quot;: &quot;45.429642, -122.721025&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.96995296563675, 45.52590463198301], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;points_str&quot;: &quot;45.525905, -122.969953&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_a09c236e982c1d939fcf38928644ca2a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fc8d62&quot;, &quot;weight&quot;: 1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#8da0cb&quot;, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;#66c2a5&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a09c236e982c1d939fcf38928644ca2a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a09c236e982c1d939fcf38928644ca2a = L.geoJson(null, {
#                 onEachFeature: geo_json_a09c236e982c1d939fcf38928644ca2a_onEachFeature,
#
#                 style: geo_json_a09c236e982c1d939fcf38928644ca2a_styler,
#         });
#
#         function geo_json_a09c236e982c1d939fcf38928644ca2a_add (data) {
#             geo_json_a09c236e982c1d939fcf38928644ca2a
#                 .addData(data)
#                 .addTo(map_dc3650b710f28d47911187ebb45cb892);
#         }
#             geo_json_a09c236e982c1d939fcf38928644ca2a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[
71479, 45.42806], [-122.71475, 45.42806]]}}, {"id": "1", "type": "Feature", "properties": {"itin_idx": 0, "totalTime": 6741, "walkTime": 1422, "transitTime": 4491, "waitingTime": 828, "walkDistance": 1635.0370298365717, "leg_id": 1, "route_id": "78", "mode": "BUS", "fromStopCode": "10305", "fromName": "Kerr & Touchstone", "toStopCode": "9985", "toName": "Beaverton Transit Center", "route_id_list": ["78", "100"], "route_id_combo": "78 to 100"}, "geometry": {"type": "LineString", "coordinates": [[-122.71475, 45.42806], [-122.71479, 45.42806], [-122.71492, 45.42808], [-122.71499, 45.42809], [-122.71505, 45.42814], [-122.71512, 45.42816], [-122.71519, 45.42818], [-122.71525, 45.42821], [-122.71537, 45.42826], [-122.71547, 45.42827], [-122.71552, 45.4283], [-122.7156, 45.42835], [-122.71568, 45.42841], [-122.71585, 45.42853], [-122.71596, 45.4286], [-122.71603, 45.42865], [-122.71617, 45.42875], [-122.71642, 45.42892], [-122.71671, 45.42913], [-122.71691, 45.42927], [-122.71705, 45.42938], [-122.71713, 45.42946], [-122.7172, 45.42954], [-122.71727, 45.42962], [-122.71734, 45.4297], [-122.71738, 45.42977], [-122.71745, 45.42989], [-122.7175, 45.42997], [-122.7178, 45.43049], [-122.71786, 45.43059], [-122.71791, 45.43067], [-122.71798, 45.43075], [-122.71806, 45.43085], [-122.71807, 45.43088], [-122.71816, 45.43096], [-122.71824, 45.43102], [-122.71828, 45.43107], [-122.71833, 45.43111], [-122.71842, 45.4311 ...

# %%
folium.GeoJsonTooltip(fields='route_id')

# %%
m = folium.Map(location=[itineraries_centroid.y, itineraries_centroid.x], zoom_start=12, tiles='CartoDB positron')

itinerary_json = itineraries_reduced[itineraries_reduced['itin_idx']==0].to_json()

folium.GeoJson(itinerary_json, name=f'{itin_route_combo}', tooltip=folium.GeoJsonTooltip(fields=['route_id'])).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2e08e02fe16a41e124ec627395a67f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2e08e02fe16a41e124ec627395a67f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2e08e02fe16a41e124ec627395a67f8 = L.map(
#                 &quot;map_f2e08e02fe16a41e124ec627395a67f8&quot;,
#                 {
#                     center: [45.48219771021486, -122.84657625135588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_285c73f54ff4e7d3bf377eea50b49f4e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2e08e02fe16a41e124ec627395a67f8);
#
#
#
#         function geo_json_f3c4a20ba245672487f73e1fd8cf59e4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f3c4a20ba245672487f73e1fd8cf59e4 = L.geoJson(null, {
#                 onEachFeature: geo_json_f3c4a20ba245672487f73e1fd8cf59e4_onEachFeature,
#
#         });
#
#         function geo_json_f3c4a20ba245672487f73e1fd8cf59e4_add (data) {
#             geo_json_f3c4a20ba245672487f73e1fd8cf59e4
#                 .addData(data)
#                 .addTo(map_f2e08e02fe16a41e124ec627395a67f8);
#         }
#             geo_json_f3c4a20ba245672487f73e1fd8cf59e4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[