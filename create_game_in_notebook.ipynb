# %%
import trimet_plan_game_helper_scripts as helpers
import geopandas as gpd
import folium
import seaborn as sns

# %%
tm_boundary = gpd.read_file("gis/export/tm_route_buffer_bounds.geojson")
trimet_crs = "EPSG:2913"

# %%
gdf_points, dist_btw_points = helpers.generate_points_within_tm_boundary(tm_boundary, trimet_crs)
gdf_points['points_str'] = gdf_points['points'].apply(lambda x: f"{round(x.y,6)}, {round(x.x,6)}")
gdf_points.explore(tiles='CartoDB positron')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7302d8bbed95ddc3e67bbea924a5f62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7302d8bbed95ddc3e67bbea924a5f62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7302d8bbed95ddc3e67bbea924a5f62 = L.map(
#                 &quot;map_f7302d8bbed95ddc3e67bbea924a5f62&quot;,
#                 {
#                     center: [45.43024778717997, -122.67529212267291],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f7302d8bbed95ddc3e67bbea924a5f62);
#
#
#
#
#
#             var tile_layer_5726c48feb37b267c2b984ef0a1ffa94 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f7302d8bbed95ddc3e67bbea924a5f62);
#
#
#             map_f7302d8bbed95ddc3e67bbea924a5f62.fitBounds(
#                 [[45.3660837316364, -122.76765818541911], [45.494411842723544, -122.58292605992672]],
#                 {}
#             );
#
#
#         function geo_json_d3ec8695dcb870abdee45e2b95649e8d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d3ec8695dcb870abdee45e2b95649e8d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d3ec8695dcb870abdee45e2b95649e8d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d3ec8695dcb870abdee45e2b95649e8d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d3ec8695dcb870abdee45e2b95649e8d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d3ec8695dcb870abdee45e2b95649e8d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d3ec8695dcb870abdee45e2b95649e8d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d3ec8695dcb870abdee45e2b95649e8d = L.geoJson(null, {
#                 onEachFeature: geo_json_d3ec8695dcb870abdee45e2b95649e8d_onEachFeature,
#
#                 style: geo_json_d3ec8695dcb870abdee45e2b95649e8d_styler,
#                 pointToLayer: geo_json_d3ec8695dcb870abdee45e2b95649e8d_pointToLayer
#         });
#
#         function geo_json_d3ec8695dcb870abdee45e2b95649e8d_add (data) {
#             geo_json_d3ec8695dcb870abdee45e2b95649e8d
#                 .addData(data)
#                 .addTo(map_f7302d8bbed95ddc3e67bbea924a5f62);
#         }
#             geo_json_d3ec8695dcb870abdee45e2b95649e8d_add({&quot;bbox&quot;: [-122.76765818541911, 45.3660837316364, -122.58292605992672, 45.494411842723544], &quot;features&quot;: [{&quot;bbox&quot;: [-122.58292605992672, 45.3660837316364, -122.58292605992672, 45.3660837316364], &quot;geometry&quot;: {&quot;coordinates&quot;: [-122.58292605992672, 45.3660837316364], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;points_str&quot;: &quot;45.366084, -122.582926&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-122.76765818541911, 45.494411842723544, -122.76765818541911, 45.494411842723544], &quot;geometry&quot;: {&quot;coordinates&quot;: [-122.76

# %%
fromplace, toplace = gdf_points['points_str'].to_numpy()
json_content = helpers.call_planner(fromplace, toplace)
itineraries_df = helpers.get_itinerary_paths(json_content)

itineraries_gdf = gpd.GeoDataFrame(itineraries_df, crs="4326", geometry="legGeometry")

unique_combinations = itineraries_df[itineraries_df['route_id']!='WALK'].groupby('itin_idx').agg(route_id_list=('route_id',list)).reset_index().drop_duplicates(subset='route_id_list')
unique_combinations['route_id_combo'] = unique_combinations['route_id_list'].apply(lambda x: " to ".join(x))

itineraries_reduced = itineraries_gdf.merge(unique_combinations, how='inner', on='itin_idx')

itineraries_centroid = itineraries_reduced.unary_union.convex_hull.centroid

# Get Unique continents
color_labels = itineraries_reduced['route_id'].unique()

# List of colors in the color palettes
hex_values = sns.color_palette("Set2", len(color_labels)).as_hex()

# Map continents to the colors
color_map = dict(zip(color_labels, hex_values))

m = folium.Map(location=[itineraries_centroid.y, itineraries_centroid.x], zoom_start=13, tiles='CartoDB positron')
origin_dest_points = folium.GeoJson(gdf_points.to_json(), name='origin_destination')
origin_dest_points.add_to(m)

for idx, itin_group in itineraries_reduced.groupby('itin_idx'):
    itin_idx = itin_group.iloc[0]['itin_idx']
    itin_route_combo = itin_group.iloc[0]['route_id_combo']
    group_json = itin_group.to_json()
    folium.GeoJson(group_json, name=f'{itin_route_combo}'
                   , tooltip=folium.GeoJsonTooltip(fields=['route_id'])
                   ,style_function=lambda feature: {
                                    'color': color_map[feature['properties']['route_id']],
                                    'weight': 1
                                }
                   ).add_to(m)
folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a58a342217de84bec3cc3fd45be15a18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a58a342217de84bec3cc3fd45be15a18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a58a342217de84bec3cc3fd45be15a18 = L.map(
#                 &quot;map_a58a342217de84bec3cc3fd45be15a18&quot;,
#                 {
#                     center: [45.44946167208135, -122.67618970036483],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_325cf912ba716f417b89159087a6cc03 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a58a342217de84bec3cc3fd45be15a18);
#
#
#
#         function geo_json_34b56003b2de105663bbc2c172f08880_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_34b56003b2de105663bbc2c172f08880 = L.geoJson(null, {
#                 onEachFeature: geo_json_34b56003b2de105663bbc2c172f08880_onEachFeature,
#
#         });
#
#         function geo_json_34b56003b2de105663bbc2c172f08880_add (data) {
#             geo_json_34b56003b2de105663bbc2c172f08880
#                 .addData(data)
#                 .addTo(map_a58a342217de84bec3cc3fd45be15a18);
#         }
#             geo_json_34b56003b2de105663bbc2c172f08880_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.58292605992672, 45.3660837316364], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;points_str&quot;: &quot;45.366084, -122.582926&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.76765818541911, 45.494411842723544], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;points_str&quot;: &quot;45.494412, -122.767658&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_0d58a31b31e12f210c7743e51a64a891_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fc8d62&quot;, &quot;weight&quot;: 1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#8da0cb&quot;, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;#66c2a5&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0d58a31b31e12f210c7743e51a64a891_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0d58a31b31e12f210c7743e51a64a891 = L.geoJson(null, {
#                 onEachFeature: geo_json_0d58a31b31e12f210c7743e51a64a891_onEachFeature,
#
#                 style: geo_json_0d58a31b31e12f210c7743e51a64a891_styler,
#         });
#
#         function geo_json_0d58a31b31e12f210c7743e51a64a891_add (data) {
