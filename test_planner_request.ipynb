# %%
import requests
import pandas as pd
import geopandas as gpd
import json
from shapely import wkt, wkb
import polyline
from shapely.geometry import LineString

# %%
base_url = "https://maps.trimet.org/otp_mod/plan"
fromplace = "45.504286,-122.646199"
toplace = "45.542102,-122.664715"
date="2023-05-02"
time="12:00"
mode="WALK,BUS,TRAM,RAIL,GONDOLA"
maxWalkDistance=1609
walkSpeed=1.34
numItineraries=3
r = requests.get(url=base_url, params={'fromPlace':fromplace, 'toPlace':toplace, 'date':date, 'time':time
                                   ,'mode':mode, 'maxWalkDistance':maxWalkDistance, 'walkSpeed':walkSpeed
                                   ,'numItineraries':numItineraries})

# %%
r.status_code
# Out:
# 200

# %%
json_content = r.json()
json_content
# Out:
# {'requestParameters': {'date': '2023-05-02',
#   'mode': 'WALK,BUS,TRAM,RAIL,GONDOLA',
#   'walkSpeed': '1.34',
#   'fromPlace': '45.504286,-122.646199',
#   'toPlace': '45.542102,-122.664715',
#   'time': '12:00',
#   'maxWalkDistance': '1609',
#   'numItineraries': '3'},
#  'plan': {'date': 1683054000000,
#   'from': {'name': 'Origin',
#    'wheelchairBoarding': 'UNKNOWN',
#    'lon': -122.646199,
#    'lat': 45.504286,
#    'orig': '',
#    'vertexType': 'NORMAL'},
#   'to': {'name': 'Destination',
#    'wheelchairBoarding': 'UNKNOWN',
#    'lon': -122.664715,
#    'lat': 45.542102,
#    'orig': '',
#    'vertexType': 'NORMAL'},
#   'itineraries': [{'duration': 2409,
#     'startTime': 1683054085000,
#     'endTime': 1683056494000,
#     'walkTime': 713,
#     'transitTime': 1283,
#     'waitingTime': 413,
#     'walkDistance': 1007.4454626807768,
#     'walkLimitExceeded': False,
#     'elevationLost': 0.8899999999999979,
#     'elevationGained': 11.54,
#     'transfers': 1,
#     'fare': {'fare': {'regular': {'currency': {'symbol': '$',
#         'currency': 'USD',
#         'defaultFractionDigits': 2,
#         'currencyCode': 'USD'},
#        'cents': 450}},
#      'details': {'regular': []}},
#     'legs': [{'startTime': 1683054085000,
#       'endTime': 1683054162000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 69.472,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Origin',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.646199,
#        'lat': 45.504286,
#        'departure': 1683054085000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'to': {'name': 'SE Division & 20th Ave',
#        'stopId': 'TriMet:14243',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '14243',
#        'lon': -122.645979,
#        'lat': 45.504888,
#        'arrival': 1683054162000,
#        'departure': 1683054163000,
#        'zoneId': 'B',
#        'stopIndex': 31,
#        'stopSequence': 33,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'wpvtGtgqkVkB??T??', 'length': 4},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 77.0,
#       'transitLeg': False,
#       'steps': [{'distance': 60.254,
#         'relativeDirection': 'DEPART',
#         'streetName': 'parking aisle',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.64586757989295,
#         'lat': 45.50428423350078,
#         'elevation': [{'first': 0.0, 'second': 16.842844584794296},
#          {'first': 10.0, 'second': 16.812844584794295},
#          {'first': 20.0, 'second': 16.822844584794296},
#          {'first': 30.0, 'second': 16.832844584794294},
#          {'first': 40.0, 'second': 16.822844584794296},
#          {'first': 50.0, 'second': 16.902844584794295},
#          {'first': 60.0, 'second': 17.072844584794296},
#          {'first': 60.25, 'second': 17.072844584794296}]},
#        {'distance': 9.218,
#         'relativeDirection': 'LEFT',
#         'streetName': 'SE Division St',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6458617,
#         'lat': 45.5048261,
#         'elevation': []}]},
#      {'startTime': 1683054163000,
#       'endTime': 1683054486000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 1558.7326850334389,
#       'pathway': False,
#       'mode': 'BUS',
#       'route': 'FX2',
#       'agencyName': 'TriMet',
#       'agencyUrl': 'https://trimet.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeColor': '61A60E',
#       'routeType': 3,
#       'routeId': 'TriMet:2',
#       'routeTextColor': 'FFFFFF',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '253',
#       'headsign': 'Portland',
#       'agencyId': 'TRIMET',
#       'tripId': 'TriMet:12336945',
#       'serviceDate': '20230502',
#       'from': {'name': 'SE Division & 20th Ave',
#        'stopId': 'TriMet:14243',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '14243',
#        'lon': -122.645979,
#        'lat': 45.504888,
#        'arrival': 1683054162000,
#        'departure': 1683054163000,
#        'zoneId': 'B',
#        'stopIndex': 31,
#        'stopSequence': 33,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'OMSI/SE Water',
#        'stopId': 'TriMet:13773',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '13773',
#        'lon': -122.663155,
#        'lat': 45.506602,
#        'arrival': 1683054486000,
#        'departure': 1683054486000,
#        'zoneId': 'B',
#        'stopIndex': 33,
#        'stopSequence': 35,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@AvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVR@FBDBDDTRDDTPHFLFD?XG?zDyCAU@G?I@GDC@CBILKVM\\Qd@IZK^I`@I^EXEZEZC\\CZ?VCX?T?V?|A?j@@T?V?PAhE',
#        'length': 77},
#       'interStopGeometry': [{'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@',
#         'length': 20},
#        {'points': 'ktvtGxaskVAvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVR@FBDBDDTRDDTPHFLFD?XG?zDyCAU@G?I@GDC@CBILKVM\\Qd@IZK^I`@I^EXEZEZC\\CZ?VCX?T?V?|A?j@@T?V?PAhE',
#         'length': 58}],
#       'routeShortName': 'FX2',
#       'routeLongName': 'Division',
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 323.0,
#       'transitLeg': True,
#       'steps': []},
#      {'startTime': 1683054486000,
#       'endTime': 1683054549000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 80.857,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'OMSI/SE Water',
#        'stopId': 'TriMet:13773',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '13773',
#        'lon': -122.663155,
#        'lat': 45.506602,
#        'arrival': 1683054486000,
#        'departure': 1683054486000,
#        'zoneId': 'B',
#        'stopIndex': 33,
#        'stopSequence': 35,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'SE Water/OMSI (Streetcar)',
#        'stopId': 'TriMet:13615',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '13615',
#        'lon': -122.663345,
#        'lat': 45.507038,
#        'arrival': 1683054549000,
#        'departure': 1683054960000,
#        'zoneId': 'B',
#        'stopIndex': 15,
#        'stopSequence': 16,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'e_wtGvstkV?PC??`@E?I?A?AE?KIFABCDCCCCC?AAE?C@?EW?',
#        'length': 20},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 63.0,
#       'transitLeg': False,
#       'steps': [{'distance': 9.343,
#         'relativeDirection': 'DEPART',
#         'streetName': 'OMSI/SE Water',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.66315529256174,
#         'lat': 45.50659372635657,
#         'elevation': [{'first': 7.063, 'second': 11.972844584794295},
#          {'first': 9.343, 'second': 11.972844584794295}]},
#        {'distance': 13.244,
#         'relativeDirection': 'LEFT',
#         'streetName': 'path',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.6632452,
#         'lat': 45.5066158,
#         'elevation': [{'first': 0.0, 'second': 11.972844584794295},
#          {'first': 13.24, 'second': 11.582844584794294}]},
#        {'distance': 42.755,
#         'relativeDirection': 'UTURN_RIGHT',
#         'streetName': 'path',
#         'absoluteDirection': 'EAST',
#         'stayOn': True,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.6634135,
#         'lat': 45.5067045,
#         'elevation': [{'first': 0.0, 'second': 11.572844584794296},
#          {'first': 7.21, 'second': 11.582844584794294},
#          {'first': 7.205, 'second': 11.582844584794294},
#          {'first': 18.825, 'second': 11.552844584794297},
#          {'first': 18.822000000000003, 'second': 11.552844584794297},
#          {'first': 33.222, 'second': 11.472844584794295}]},
#        {'distance': 15.515,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'SE Water/OMSI',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': True,
#         'bogusName': False,
#         'lon': -122.6633713,
#         'lat': 45.5069134,
#         'elevation': []}]},
#      {'startTime': 1683054960000,
#       'endTime': 1683055920000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 3454.115446597877,
#       'pathway': False,
#       'mode': 'TRAM',
#       'route': 'Portland Streetcar - B Loop',
#       'agencyName': 'Portland Streetcar',
#       'agencyUrl': 'https://portlandstreetcar.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeColor': '3E0099',
#       'routeType': 0,
#       'routeId': 'TriMet:195',
#       'routeTextColor': 'FFFFFF',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '58',
#       'headsign': 'PSU via Pearl',
#       'agencyId': 'PSC',
#       'tripId': 'TriMet:12352153',
#       'serviceDate': '20230502',
#       'from': {'name': 'SE Water/OMSI (Streetcar)',
#        'stopId': 'TriMet:13615',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '13615',
#        'lon': -122.663345,
#        'lat': 45.507038,
#        'arrival': 1683054549000,
#        'departure': 1683054960000,
#        'zoneId': 'B',
#        'stopIndex': 15,
#        'stopSequence': 16,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'NE Broadway & 2nd (Streetcar)',
#        'stopId': 'TriMet:13618',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '13618',
#        'lon': -122.663538,
#        'lat': 45.535034,
#        'arrival': 1683055920000,
#        'departure': 1683055921000,
#        'zoneId': 'B',
#        'stopIndex': 26,
#        'stopSequence': 27,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': '}awtGxttkVE?I?k@?G?GAUKKGIIECMQIOeBqDMUCGEEEGIGGEGEIEIAICOAM@I@]HE?G?C?ICECCCEECECGCIAGAI?I?q@?W?I?EAGCICCACCEeA?g@?E?K?KAQ?qB?o@?}AAW?s@?]?e@?uBAC?O?S?cA?_@?Y?S?yBA{B?C?M?M?O?u@?M?k@AO?O?oBAW?m@?K?A?g@?S?Q?O?kB@q@A{A?cBA[?M?s@?{A?u@?y@?_@?w@Ai@?i@?}B?O?OAo@?A?u@?W?mC?mCAS?{B?UBiD?c@?MA]CU?_AAq@?]?M?c@?wA?}@?g@?U?I?CAM?mB?K?[?e@?M???W?_@AM?E?iC?yBAS?eA?iA?mCAmC?M?qBAO?C@K?q@AS?c@?SAAV?\\?v@?t@?N?XAX?nD?lD',
#        'length': 168},
#       'interStopGeometry': [{'points': '}awtGxttkVE?I?k@?G?GAUKKGIIECMQIOeBqDMUCGEEEGIGGEGEIEIAICOAM@I@]HE?G?C?ICECCCEECECGCIAGAI?I?q@?W?I?EAGCICCACCEeA?g@?',
#         'length': 51},
#        {'points': 'otwtG`etkVE?K?KAQ?qB?o@?}AAW?s@?]?e@?uBA', 'length': 13},
#        {'points': 'efxtGzdtkVC?O?S?cA?_@?Y?S?yBA{B?', 'length': 10},
#        {'points': 'usxtGxdtkVC?M?M?O?u@?M?k@AO?O?oBAW?m@?', 'length': 13},
#        {'points': 'k_ytGtdtkVK?A?g@?S?Q?O?kB@q@A{A?cBA[?M?s@?', 'length': 14},
#        {'points': 'spytGrdtkV{A?u@?y@?_@?w@Ai@?i@?}B?O?OAo@?A?u@?',
#         'length': 14},
#        {'points': 'qdztGndtkVW?mC?mCAS?{B?UBiD?c@?MA]CU?_AAq@?]?M?c@?',
#         'length': 17},
#        {'points': '}a{tGhdtkVwA?}@?g@?U?I?CAM?mB?K?[?e@?M???', 'length': 14},
#        {'points': 'wo{tGfdtkVW?_@AM?E?iC?yBAS?eA?', 'length': 9},
#        {'points': 'a}{tGbdtkViA?mCAmC?M?qBAO?C@K?q@AS?', 'length': 11},
#        {'points': 'mo|tG~ctkVc@?SAAV?\\?v@?t@?N?XAX?nD?lD', 'length': 12}],
#       'routeLongName': 'Portland Streetcar - B Loop',
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 960.0,
#       'transitLeg': True,
#       'steps': []},
#      {'startTime': 1683055921000,
#       'endTime': 1683056494000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 856.8840000000001,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'NE Broadway & 2nd (Streetcar)',
#        'stopId': 'TriMet:13618',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '13618',
#        'lon': -122.663538,
#        'lat': 45.535034,
#        'arrival': 1683055920000,
#        'departure': 1683055921000,
#        'zoneId': 'B',
#        'stopIndex': 26,
#        'stopSequence': 27,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'Destination',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.664715,
#        'lat': 45.542102,
#        'arrival': 1683056494000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'legGeometry': {'points': '}p|tGbvtkV?D?@C@G??PQ?Q?Q?_@?u@AoC??dBoB?c@?O?kC?w@AgCAaE?aA?}BAw@?gCA@`B?P',
#        'length': 26},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 573.0,
#       'transitLeg': False,
#       'steps': [{'distance': 3.254,
#         'relativeDirection': 'DEPART',
#         'streetName': 'path',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.66353797686243,
#         'lat': 45.5350370105401,
#         'elevation': [{'first': 1.845, 'second': 39.402844584794295},
#          {'first': 3.255, 'second': 39.372844584794294}]},
#        {'distance': 6.866,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'path',
#         'absoluteDirection': 'NORTH',
#         'stayOn': True,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.6635798,
#         'lat': 45.5350372,
#         'elevation': [{'first': 0.0, 'second': 39.372844584794294},
#          {'first': 6.87, 'second': 39.3528445847943}]},
#        {'distance': 7.282,
#         'relativeDirection': 'LEFT',
#         'streetName': 'NE Broadway',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.663586,
#         'lat': 45.5350988,
#         'elevation': [{'first': 0.0, 'second': 39.3528445847943},
#          {'first': 7.28, 'second': 39.3028445847943}]},
#        {'distance': 156.909,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE 2nd Ave',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6636795,
#         'lat': 45.5350989,
#         'elevation': [{'first': 0.0, 'second': 39.3028445847943},
#          {'first': 10.0, 'second': 39.5728445847943},
#          {'first': 19.32, 'second': 39.5228445847943},
#          {'first': 19.315, 'second': 39.5228445847943},
#          {'first': 29.555, 'second': 39.5728445847943},
#          {'first': 29.556, 'second': 39.5728445847943},
#          {'first': 39.556, 'second': 39.612844584794296},
#          {'first': 47.106, 'second': 39.652844584794295},
#          {'first': 47.103, 'second': 39.652844584794295},
#          {'first': 57.103, 'second': 39.7128445847943},
#          {'first': 67.10300000000001, 'second': 39.7728445847943},
#          {'first': 77.503, 'second': 39.81284458479429},
#          {'first': 77.505, 'second': 39.81284458479429},
#          {'first': 87.505, 'second': 39.84284458479429},
#          {'first': 97.505, 'second': 39.9128445847943},
#          {'first': 107.505, 'second': 39.9928445847943},
#          {'first': 117.505, 'second': 40.09284458479429},
#          {'first': 127.505, 'second': 40.1928445847943},
#          {'first': 137.505, 'second': 40.2828445847943},
#          {'first': 147.505, 'second': 40.3828445847943},
#          {'first': 156.905, 'second': 40.5228445847943}]},
#        {'distance': 39.675,
#         'relativeDirection': 'LEFT',
#         'streetName': 'NE Hancock St',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.66367,
#         'lat': 45.53651,
#         'elevation': [{'first': 0.0, 'second': 40.5228445847943},
#          {'first': 10.0, 'second': 40.862844584794296},
#          {'first': 20.0, 'second': 41.0528445847943},
#          {'first': 30.0, 'second': 41.0228445847943},
#          {'first': 39.68, 'second': 40.84284458479429}]},
#        {'distance': 597.549,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE Rodney Ave',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6641794,
#         'lat': 45.5365107,
#         'elevation': [{'first': 0.0, 'second': 40.84284458479429},
#          {'first': 10.0, 'second': 40.502844584794296},
#          {'first': 20.0, 'second': 40.5328445847943},
#          {'first': 30.0, 'second': 40.6328445847943},
#          {'first': 40.0, 'second': 40.762844584794294},
#          {'first': 50.0, 'second': 40.862844584794296},
#          {'first': 62.69, 'second': 41.002844584794296},
#          {'first': 62.692, 'second': 41.002844584794296},
#          {'first': 72.69200000000001, 'second': 41.112844584794296},
#          {'first': 82.202, 'second': 41.182844584794296},
#          {'first': 82.206, 'second': 41.182844584794296},
#          {'first': 92.206, 'second': 41.292844584794295},
#          {'first': 102.206, 'second': 41.3928445847943},
#          {'first': 112.206, 'second': 41.4928445847943},
#          {'first': 122.206, 'second': 41.622844584794294},
#          {'first': 132.20600000000002, 'second': 41.752844584794296},
#          {'first': 142.20600000000002, 'second': 41.872844584794294},
#          {'first': 152.20600000000002, 'second': 41.98284458479429},
#          {'first': 162.20600000000002, 'second': 42.1028445847943},
#          {'first': 169.316, 'second': 42.20284458479429},
#          {'first': 169.316, 'second': 42.20284458479429},
#          {'first': 179.316, 'second': 42.332844584794294},
#          {'first': 189.316, 'second': 42.542844584794295},
#          {'first': 199.316, 'second': 42.84284458479429},
#          {'first': 209.316, 'second': 43.182844584794296},
#          {'first': 219.316, 'second': 43.5228445847943},
#          {'first': 229.316, 'second': 43.872844584794294},
#          {'first': 239.316, 'second': 44.23284458479429},
#          {'first': 249.316, 'second': 44.5528445847943},
#          {'first': 259.31600000000003, 'second': 44.8928445847943},
#          {'first': 269.31600000000003, 'second': 45.252844584794296},
#          {'first': 276.466, 'second': 45.472844584794295},
#          {'first': 276.468, 'second': 45.472844584794295},
#          {'first': 286.468, 'second': 45.682844584794296},
#          {'first': 296.468, 'second': 45.70284458479429},
#          {'first': 306.468, 'second': 45.81284458479429},
#          {'first': 316.468, 'second': 45.872844584794294},
#          {'first': 326.468, 'second': 45.95284458479429},
#          {'first': 336.468, 'second': 46.042844584794295},
#          {'first': 346.468, 'second': 46.09284458479429},
#          {'first': 356.468, 'second': 46.182844584794296},
#          {'first': 366.468, 'second': 46.2728445847943},
#          {'first': 376.468, 'second': 46.31284458479429},
#          {'first': 383.678, 'second': 46.4128445847943},
#          {'first': 383.682, 'second': 46.4128445847943},
#          {'first': 393.682, 'second': 46.5328445847943},
#          {'first': 403.682, 'second': 46.67284458479429},
#          {'first': 413.682, 'second': 46.7728445847943},
#          {'first': 423.682, 'second': 46.862844584794296},
#          {'first': 433.682, 'second': 46.95284458479429},
#          {'first': 443.682, 'second': 47.0528445847943},
#          {'first': 453.682, 'second': 47.17284458479429},
#          {'first': 463.682, 'second': 47.262844584794294},
#          {'first': 473.682, 'second': 47.332844584794294},
#          {'first': 483.682, 'second': 47.42284458479429},
#          {'first': 491.002, 'second': 47.4928445847943},
#          {'first': 490.999, 'second': 47.4928445847943},
#          {'first': 500.999, 'second': 47.7128445847943},
#          {'first': 510.999, 'second': 47.73284458479429},
#          {'first': 522.089, 'second': 47.98284458479429},
#          {'first': 522.09, 'second': 47.98284458479429},
#          {'first': 532.09, 'second': 48.2428445847943},
#          {'first': 542.09, 'second': 48.4928445847943},
#          {'first': 552.09, 'second': 48.752844584794296},
#          {'first': 562.09, 'second': 49.002844584794296},
#          {'first': 572.09, 'second': 49.262844584794294},
#          {'first': 582.09, 'second': 49.5328445847943},
#          {'first': 592.09, 'second': 49.792844584794295},
#          {'first': 597.5500000000001, 'second': 49.9428445847943}]},
#        {'distance': 45.349,
#         'relativeDirection': 'LEFT',
#         'streetName': 'NE Knott St',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6641342,
#         'lat': 45.5418845,
#         'elevation': [{'first': 0.0, 'second': 49.9428445847943},
#          {'first': 10.0, 'second': 49.972844584794295},
#          {'first': 20.0, 'second': 49.9428445847943},
#          {'first': 30.0, 'second': 49.9128445847943},
#          {'first': 40.0, 'second': 49.8928445847943},
#          {'first': 45.35, 'second': 49.8228445847943}]}]}],
#     'tooSloped': False},
#    {'duration': 2711,
#     'startTime': 1683054085000,
#     'endTime': 1683056796000,
#     'walkTime': 374,
#     'transitTime': 1917,
#     'waitingTime': 420,
#     'walkDistance': 511.3899552205438,
#     'walkLimitExceeded': False,
#     'elevationLost': 5.439999999999999,
#     'elevationGained': 4.91,
#     'transfers': 1,
#     'fare': {'fare': {'regular': {'currency': {'symbol': '$',
#         'currency': 'USD',
#         'defaultFractionDigits': 2,
#         'currencyCode': 'USD'},
#        'cents': 250}},
#      'details': {'regular': []}},
#     'legs': [{'startTime': 1683054085000,
#       'endTime': 1683054162000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 69.472,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Origin',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.646199,
#        'lat': 45.504286,
#        'departure': 1683054085000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'to': {'name': 'SE Division & 20th Ave',
#        'stopId': 'TriMet:14243',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '14243',
#        'lon': -122.645979,
#        'lat': 45.504888,
#        'arrival': 1683054162000,
#        'departure': 1683054163000,
#        'zoneId': 'B',
#        'stopIndex': 31,
#        'stopSequence': 33,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'wpvtGtgqkVkB??T??', 'length': 4},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 77.0,
#       'transitLeg': False,
#       'steps': [{'distance': 60.254,
#         'relativeDirection': 'DEPART',
#         'streetName': 'parking aisle',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.64586757989295,
#         'lat': 45.50428423350078,
#         'elevation': [{'first': 0.0, 'second': 16.842844584794296},
#          {'first': 10.0, 'second': 16.812844584794295},
#          {'first': 20.0, 'second': 16.822844584794296},
#          {'first': 30.0, 'second': 16.832844584794294},
#          {'first': 40.0, 'second': 16.822844584794296},
#          {'first': 50.0, 'second': 16.902844584794295},
#          {'first': 60.0, 'second': 17.072844584794296},
#          {'first': 60.25, 'second': 17.072844584794296}]},
#        {'distance': 9.218,
#         'relativeDirection': 'LEFT',
#         'streetName': 'SE Division St',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6458617,
#         'lat': 45.5048261,
#         'elevation': []}]},
#      {'startTime': 1683054163000,
#       'endTime': 1683055200000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 4811.395650329354,
#       'pathway': False,
#       'mode': 'BUS',
#       'route': 'FX2',
#       'agencyName': 'TriMet',
#       'agencyUrl': 'https://trimet.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeColor': '61A60E',
#       'routeType': 3,
#       'routeId': 'TriMet:2',
#       'routeTextColor': 'FFFFFF',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '253',
#       'headsign': 'Portland',
#       'agencyId': 'TRIMET',
#       'tripId': 'TriMet:12336945',
#       'serviceDate': '20230502',
#       'from': {'name': 'SE Division & 20th Ave',
#        'stopId': 'TriMet:14243',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '14243',
#        'lon': -122.645979,
#        'lat': 45.504888,
#        'arrival': 1683054162000,
#        'departure': 1683054163000,
#        'zoneId': 'B',
#        'stopIndex': 31,
#        'stopSequence': 33,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'SW 6th & Taylor',
#        'stopId': 'TriMet:7800',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '7800',
#        'lon': -122.679316,
#        'lat': 45.517604,
#        'arrival': 1683055200000,
#        'departure': 1683055200000,
#        'zoneId': 'B',
#        'stopIndex': 38,
#        'stopSequence': 40,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@AvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVR@FBDBDDTRDDTPHFLFD?XG?zDyCAU@G?I@GDC@CBILKVM\\Qd@IZK^I`@I^EXEZEZC\\CZ?VCX?T?V?|A?j@@T?V?PAhEAr@?hAAFCN?F?b@?X@J@NDTBJDNDH@FFJJPZh@`@r@n@jAx@tAt@rA~@`Bx@xAvBvDfAlBf@z@HNFJ@DDHFNFPDRFPDNBHDRBHHXHZFTJj@|@jEH`@BNAL?HA\\?D?D?HAFAH?FAFCFCFINEFCDC@CBC@IBaBp@y@ZiA`@_@PWJOHOHq@\\OHQHc@TSLKHOJEDGFGDo@r@EFMLQPGDQLMHEBGBKDQHIBqAb@CBKBQFG@SDI@s@NODE@MDGDGBEDGDEDEBEFGHEHEDEHCHCDGTIZAHAHAJ?HAJ?J?DAL?H?R?nB?BCTATAvC?X@N@^@ZBl@@fA?J?`@?N?^?bA?\\AjB?XA\\AXC^Eb@AHCNALK?Y?m@EQAUGSG]MGCWMKE}@a@y@]KGQ`AMv@Mn@G\\ADq@|DCNaAc@MGs@[yBaAMG{BcAGCgBw@EAUMGA{@a@aAc@mBy@?AWKcCgAeCgAKEmBu@MEMIkBy@IEQG{Aq@',
#        'length': 278},
#       'interStopGeometry': [{'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@',
#         'length': 20},
#        {'points': 'ktvtGxaskVAvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVR@FBDBDDTRDDTPHFLFD?XG?zDyCAU@G?I@GDC@CBILKVM\\Qd@IZK^I`@I^EXEZEZC\\CZ?VCX?T?V?|A?j@@T?V?PAhE',
#         'length': 58},
#        {'points': '}~vtGvstkVAr@?hAAFCN?F?b@?X@J@NDTBJDNDH@FFJJPZh@`@r@n@jAx@tAt@rA~@`Bx@xAvBvDfAlBf@z@HNFJ@DDHFNFPDRFPDNBHDRBHHXHZFTJj@|@jE',
#         'length': 44},
#        {'points': 'cfvtGrivkVH`@BNAL?HA\\?D?D?HAFAH?FAFCFCFINEFCDC@CBC@IBaBp@y@ZiA`@_@PWJOHOHq@\\OHQHc@TSLKHOJEDGFGDo@r@EFMLQPGDQLMHEBGBKDQHIBqAb@CBKBQFG@SDI@s@NODE@MDGDGBEDGDEDEBEFGHEHEDEHCHCDGTIZAHAHAJ?HAJ?J?DAL?H?R?nB?BCTATAvC?X@N@^@ZBl@@fA?J?`@',
#         'length': 100},
#        {'points': '}gwtGd{wkV?N?^?bA?\\AjB?XA\\AXC^Eb@AHCNALK?Y?m@EQAUGSG]MGCWMKE}@a@y@]KGQ`AMv@Mn@',
#         'length': 30},
#        {'points': 'auwtGdjxkVG\\ADq@|DCNaAc@MGs@[yBaAMG{BcAGCgBw@EAUMGA{@a@aAc@mBy@?A',
#         'length': 20},
#        {'points': 'ioxtGpdxkVWKcCgAeCgAKEmBu@MEMIkBy@IEQG{Aq@', 'length': 12}],
#       'routeShortName': 'FX2',
#       'routeLongName': 'Division',
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 1037.0,
#       'transitLeg': True,
#       'steps': []},
#      {'startTime': 1683055200000,
#       'endTime': 1683055262000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 79.987,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'SW 6th & Taylor',
#        'stopId': 'TriMet:7800',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '7800',
#        'lon': -122.679316,
#        'lat': 45.517604,
#        'arrival': 1683055200000,
#        'departure': 1683055200000,
#        'zoneId': 'B',
#        'stopIndex': 38,
#        'stopSequence': 40,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'SW 6th & Salmon',
#        'stopId': 'TriMet:7789',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '7789',
#        'lon': -122.679687,
#        'lat': 45.516934,
#        'arrival': 1683055262000,
#        'departure': 1683055680000,
#        'zoneId': 'B',
#        'stopIndex': 1,
#        'stopSequence': 2,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': '}cytGpxwkV~Ar@LFJDJF', 'length': 5},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 62.0,
#       'transitLeg': False,
#       'steps': [{'distance': 79.987,
#         'relativeDirection': 'DEPART',
#         'streetName': 'sidewalk',
#         'absoluteDirection': 'SOUTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.6792871801376,
#         'lat': 45.517596405690654,
#         'elevation': [{'first': 57.487, 'second': 20.042844584794295},
#          {'first': 65.127, 'second': 20.092844584794296},
#          {'first': 65.128, 'second': 20.092844584794296},
#          {'first': 72.888, 'second': 20.342844584794296}]}]},
#      {'startTime': 1683055680000,
#       'endTime': 1683056560000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 3594.3326510154047,
#       'pathway': False,
#       'mode': 'BUS',
#       'route': '4',
#       'agencyName': 'TriMet',
#       'agencyUrl': 'https://trimet.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeType': 3,
#       'routeId': 'TriMet:4',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '411',
#       'headsign': 'St Johns via Albina Ave',
#       'agencyId': 'TRIMET',
#       'tripId': 'TriMet:12337150',
#       'serviceDate': '20230502',
#       'from': {'name': 'SW 6th & Salmon',
#        'stopId': 'TriMet:7789',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '7789',
#        'lon': -122.679687,
#        'lat': 45.516934,
#        'arrival': 1683055262000,
#        'departure': 1683055680000,
#        'zoneId': 'B',
#        'stopIndex': 1,
#        'stopSequence': 2,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'N Williams & NE Graham',
#        'stopId': 'TriMet:6362',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode':
ave',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.66663828036148,
#         'lat': 45.54273334324396,
#         'elevation': [{'first': 2.998, 'second': 50.582844584794294},
#          {'first': 13.998000000000001, 'second': 50.762844584794294}]},
#        {'distance': 195.315,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE Graham St',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6666355,
#         'lat': 45.5428592,
#         'elevation': [{'first': 0.0, 'second': 50.762844584794294},
#          {'first': 10.0, 'second': 50.8528445847943},
#          {'first': 20.0, 'second': 51.112844584794296},
#          {'first': 30.0, 'second': 51.3528445847943},
#          {'first': 40.0, 'second': 51.6028445847943},
#          {'first': 50.0, 'second': 51.902844584794295},
#          {'first': 60.0, 'second': 52.1628445847943},
#          {'first': 70.0, 'second': 52.34284458479429},
#          {'first': 80.0, 'second': 52.6028445847943},
#          {'first': 90.0, 'second': 52.872844584794294},
#          {'first': 100.0, 'second': 53.20284458479429},
#          {'first': 110.0, 'second': 53.432844584794296},
#          {'first': 120.0, 'second': 53.64284458479429},
#          {'first': 130.0, 'second': 53.8828445847943},
#          {'first': 140.0, 'second': 54.122844584794294},
#          {'first': 150.0, 'second': 54.3828445847943},
#          {'first': 160.0, 'second': 54.682844584794296},
#          {'first': 170.0, 'second': 54.902844584794295},
#          {'first': 180.0, 'second': 55.14284458479429},
#          {'first': 190.0, 'second': 55.1928445847943},
#          {'first': 195.32, 'second': 55.17284458479429}]},
#        {'distance': 107.137,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE Rodney Ave',
#         'absoluteDirection': 'SOUTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6641276,
#         'lat': 45.542848,
#         'elevation': [{'first': 0.0, 'second': 55.17284458479429},
#          {'first': 10.0, 'second': 54.6928445847943},
#          {'first': 20.0, 'second': 54.17284458479429},
#          {'first': 30.0, 'second': 53.652844584794295},
#          {'first': 40.0, 'second': 53.1028445847943},
#          {'first': 50.0, 'second': 52.542844584794295},
#          {'first': 60.0, 'second': 51.9928445847943},
#          {'first': 70.0, 'second': 51.45284458479429},
#          {'first': 80.0, 'second': 50.8928445847943},
#          {'first': 90.0, 'second': 50.402844584794295},
#          {'first': 100.0, 'second': 50.152844584794295},
#          {'first': 107.14, 'second': 49.9428445847943}]},
#        {'distance': 45.349,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE Knott St',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6641342,
#         'lat': 45.5418845,
#         'elevation': [{'first': 0.0, 'second': 49.9428445847943},
#          {'first': 10.0, 'second': 49.972844584794295},
#          {'first': 20.0, 'second': 49.9428445847943},
#          {'first': 30.0, 'second': 49.9128445847943},
#          {'first': 40.0, 'second': 49.8928445847943},
#          {'first': 45.35, 'second': 49.8228445847943}]}]}],
#     'tooSloped': False},
#    {'duration': 1808,
#     'startTime': 1683056212000,
#     'endTime': 1683058020000,
#     'walkTime': 419,
#     'transitTime': 1088,
#     'waitingTime': 301,
#     'walkDistance': 555.6388656691045,
#     'walkLimitExceeded': False,
#     'elevationLost': 2.569999999999994,
#     'elevationGained': 0.6999999999999962,
#     'transfers': 1,
#     'fare': {'fare': {'regular': {'currency': {'symbol': '$',
#         'currency': 'USD',
#         'defaultFractionDigits': 2,
#         'currencyCode': 'USD'},
#        'cents': 250}},
#      'details': {'regular': []}},
#     'legs': [{'startTime': 1683056212000,
#       'endTime': 1683056289000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 69.472,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Origin',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.646199,
#        'lat': 45.504286,
#        'departure': 1683056212000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'to': {'name': 'SE Division & 20th Ave',
#        'stopId': 'TriMet:14243',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '14243',
#        'lon': -122.645979,
#        'lat': 45.504888,
#        'arrival': 1683056289000,
#        'departure': 1683056290000,
#        'zoneId': 'B',
#        'stopIndex': 65,
#        'stopSequence': 66,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'wpvtGtgqkVkB??T??', 'length': 4},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 77.0,
#       'transitLeg': False,
#       'steps': [{'distance': 60.254,
#         'relativeDirection': 'DEPART',
#         'streetName': 'parking aisle',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.64586757989295,
#         'lat': 45.50428423350078,
#         'elevation': [{'first': 0.0, 'second': 16.842844584794296},
#          {'first': 10.0, 'second': 16.812844584794295},
#          {'first': 20.0, 'second': 16.822844584794296},
#          {'first': 30.0, 'second': 16.832844584794294},
#          {'first': 40.0, 'second': 16.822844584794296},
#          {'first': 50.0, 'second': 16.902844584794295},
#          {'first': 60.0, 'second': 17.072844584794296},
#          {'first': 60.25, 'second': 17.072844584794296}]},
#        {'distance': 9.218,
#         'relativeDirection': 'LEFT',
#         'streetName': 'SE Division St',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6458617,
#         'lat': 45.5048261,
#         'elevation': []}]},
#      {'startTime': 1683056290000,
#       'endTime': 1683056697000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 1938.1212784339198,
#       'pathway': False,
#       'mode': 'BUS',
#       'route': '10',
#       'agencyName': 'TriMet',
#       'agencyUrl': 'https://trimet.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeType': 3,
#       'routeId': 'TriMet:10',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '1037',
#       'headsign': 'Portland',
#       'agencyId': 'TRIMET',
#       'tripId': 'TriMet:12338601',
#       'serviceDate': '20230502',
#       'from': {'name': 'SE Division & 20th Ave',
#        'stopId': 'TriMet:14243',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '14243',
#        'lon': -122.645979,
#        'lat': 45.504888,
#        'arrival': 1683056289000,
#        'departure': 1683056290000,
#        'zoneId': 'B',
#        'stopIndex': 65,
#        'stopSequence': 66,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'SE Madison & Grand',
#        'stopId': 'TriMet:3633',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '3633',
#        'lon': -122.6606,
#        'lat': 45.513009,
#        'arrival': 1683056697000,
#        'departure': 1683056697000,
#        'zoneId': 'B',
#        'stopIndex': 70,
#        'stopSequence': 71,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@AvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVGLWh@O^e@`AeA|BMOCACAC?w@?Y@W?e@?_AA[?s@?mC?o@A}A?oC?mCAmC?o@?_BA_C?K??rAA|B?dD',
#        'length': 64},
#       'interStopGeometry': [{'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@',
#         'length': 20},
#        {'points': 'ktvtGxaskVAvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVGLWh@O^e@`A',
#         'length': 20},
#        {'points': 'u{vtGztskVeA|BMOCACAC?w@?Y@W?e@?_AA[?s@?mC?o@A',
#         'length': 15},
#        {'points': 'smwtGbxskV}A?oC?mCAmC?o@?', 'length': 6},
#        {'points': 'm_xtG`xskV_BA_C?K??rAA|B?dD', 'length': 7}],
#       'routeShortName': '10',
#       'routeLongName': 'Harold St',
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 407.0,
#       'transitLeg': True,
#       'steps': []},
#      {'startTime': 1683056697000,
#       'endTime': 1683056860000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 214.776,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'SE Madison & Grand',
#        'stopId': 'TriMet:3633',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '3633',
#        'lon': -122.6606,
#        'lat': 45.513009,
#        'arrival': 1683056697000,
#        'departure': 1683056697000,
#        'zoneId': 'B',
#        'stopIndex': 70,
#        'stopSequence': 71,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'SE Grand & Main',
#        'stopId': 'TriMet:2170',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '2170',
#        'lon': -122.660658,
#        'lat': 45.51341,
#        'arrival': 1683056860000,
#        'departure': 1683057159000,
#        'zoneId': 'B',
#        'stopIndex': 7,
#        'stopSequence': 8,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': '{fxtGxctkV?gDmC?AlA?bB', 'length': 5},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 163.0,
#       'transitLeg': False,
#       'steps': [{'distance': 65.014,
#         'relativeDirection': 'DEPART',
#         'streetName': 'SE Madison St',
#         'absoluteDirection': 'EAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.66060031541903,
#         'lat': 45.512941926833896,
#         'elevation': []},
#        {'distance': 80.05,
#         'relativeDirection': 'LEFT',
#         'streetName': 'SE 6th Ave',
#         'absoluteDirection': 'NORTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6597659,
#         'lat': 45.51294,
#         'elevation': [{'first': 0.0, 'second': 15.942844584794296},
#          {'first': 10.0, 'second': 15.912844584794296},
#          {'first': 20.0, 'second': 15.772844584794296},
#          {'first': 30.0, 'second': 15.652844584794295},
#          {'first': 40.0, 'second': 15.542844584794295},
#          {'first': 50.0, 'second': 15.422844584794296},
#          {'first': 60.0, 'second': 15.312844584794295},
#          {'first': 70.0, 'second': 15.222844584794295},
#          {'first': 80.05, 'second': 15.182844584794296}]},
#        {'distance': 69.712,
#         'relativeDirection': 'LEFT',
#         'streetName': 'SE Main St',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6597616,
#         'lat': 45.5136599,
#         'elevation': [{'first': 0.0, 'second': 15.182844584794296},
#          {'first': 10.0, 'second': 15.332844584794294},
#          {'first': 20.0, 'second': 15.572844584794296},
#          {'first': 30.51, 'second': 15.752844584794296}]}]},
#      {'startTime': 1683057159000,
#       'endTime': 1683057840000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 3211.21454112925,
#       'pathway': False,
#       'mode': 'BUS',
#       'route': '6',
#       'agencyName': 'TriMet',
#       'agencyUrl': 'https://trimet.org/',
#       'agencyTimeZoneOffset': -25200000,
#       'routeType': 3,
#       'routeId': 'TriMet:6',
#       'interlineWithPreviousLeg': False,
#       'tripBlockId': '604',
#       'headsign': 'Jantzen Beach via Delta Park',
#       'agencyId': 'TRIMET',
#       'tripId': 'TriMet:12337532',
#       'serviceDate': '20230502',
#       'from': {'name': 'SE Grand & Main',
#        'stopId': 'TriMet:2170',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '2170',
#        'lon': -122.660658,
#        'lat': 45.51341,
#        'arrival': 1683056860000,
#        'departure': 1683057159000,
#        'zoneId': 'B',
#        'stopIndex': 7,
#        'stopSequence': 8,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'NE M L King & Knott',
#        'stopId': 'TriMet:5930',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '5930',
#        'lon': -122.661479,
#        'lat': 45.542015,
#        'arrival': 1683057840000,
#        'departure': 1683057841000,
#        'zoneId': 'B',
#        'stopIndex': 18,
#        'stopSequence': 19,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'legGeometry': {'points': 'yixtGzdtkVW?Y?S?yBA{B?C?M?M?O?u@?M?k@AO?O?oBAW?m@?K?A?g@?S?Q?O?kB@q@A{A?cBA[?M?s@?{A?u@?y@?_@?w@Ai@?i@?}B?O?OAo@?A?u@?W?mC?mCAS?{B?UBiD?c@?MA]CU?_AAq@?]?M?c@?wA?}@?g@?U?I?CAM?mB?K?[?e@?M???W?_@AM?E?iC?yBAS?eB?i@?mCAmC?M?qBAO?C@K?q@Aw@?SAS?U?Y?]?k@?k@NOHKHGHIJMVMXMZS^GFCBGDI@I?_A?]?WLsA?S?a@KM@YA[?eA?y@?mBAoA?{@CO?O?_@?s@AO@M@w@?yB?[A',
#        'length': 134},
#       'interStopGeometry': [{'points': 'yixtGzdtkVW?Y?S?yBA{B?', 'length': 6},
#        {'points': 'usxtGxdtkVC?M?M?O?u@?M?k@AO?O?oBAW?m@?', 'length': 13},
#        {'points': 'k_ytGtdtkVK?A?g@?S?Q?O?kB@q@A{A?cBA[?M?s@?', 'length': 14},
#        {'points': 'spytGrdtkV{A?u@?y@?_@?w@Ai@?i@?}B?O?OAo@?A?u@?',
#         'length': 14},
#        {'points': 'qdztGndtkVW?mC?mCAS?{B?UBiD?c@?MA]CU?_AAq@?]?M?c@?',
#         'length': 17},
#        {'points': '}a{tGhdtkVwA?}@?g@?U?I?CAM?mB?K?[?e@?M???', 'length': 14},
#        {'points': 'wo{tGfdtkVW?_@AM?E?iC?yBAS?eB?', 'length': 9},
#        {'points': 'a~{tGbdtkVi@?mCAmC?M?qBAO?C@K?q@Aw@?SAS?U?Y?',
#         'length': 15},
#        {'points': 'is|tG|ctkV]?k@?k@NOHKHGHIJMVMXMZS^GFCBGDI@I?_A?]?WLsA?',
#         'length': 21},
#        {'points': '}a}tGfjtkVS?a@KM@YA[?eA?y@?mBAoA?{@C', 'length': 11},
#        {'points': 'qq}tGtitkVO?O?_@?s@AO@M@w@?yB?[A', 'length': 10}],
#       'alerts': [{'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'Bus service may be experiencing delays due to a mechanical issue near Jantzen Beach.',
#         'effectiveStartDate': 1683252103000},
#        {'alertUrl': 'http://trimet.org/alerts/',
#         'alertDescriptionText': 'The westbound stop SW Jefferson & 10th (Stop ID 3049) is closed. Use temp stop approximately one block east at W Jefferson & Park Ave (Stop ID 14221).',
#         'effectiveStartDate': 1677867298000}],
#       'routeShortName': '6',
#       'routeLongName': 'Martin Luther King Jr Blvd',
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 681.0,
#       'transitLeg': True,
#       'steps': []},
#      {'startTime': 1683057841000,
#       'endTime': 1683058020000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 271.289,
#       'pathway': False,
#       'mode': 'WALK',
#       'route': '',
#       'agencyTimeZoneOffset': -25200000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'NE M L King & Knott',
#        'stopId': 'TriMet:5930',
#        'wheelchairBoarding': 'UNKNOWN',
#        'stopCode': '5930',
#        'lon': -122.661479,
#        'lat': 45.542015,
#        'arrival': 1683057840000,
#        'departure': 1683057841000,
#        'zoneId': 'B',
#        'stopIndex': 18,
#        'stopSequence': 19,
#        'vertexType': 'TRANSIT',
#        'boardAlightType': 'DEFAULT'},
#       'to': {'name': 'Destination',
#        'wheelchairBoarding': 'UNKNOWN',
#        'lon': -122.664715,
#        'lat': 45.542102,
#        'arrival': 1683058020000,
#        'orig': '',
#        'vertexType': 'NORMAL'},
#       'legGeometry': {'points': 'w|}tGfitkV?L?T`@A?N?jB?p@?b@?\\AnA?pD@`B?P',
#        'length': 13},
#       'rentedBike': False,
#       'rentedCar': False,
#       'rentedVehicle': False,
#       'hailedCar': False,
#       'flexDrtAdvanceBookMin': 0.0,
#       'duration': 179.0,
#       'transitLeg': False,
#       'steps': [{'distance': 13.607000000000001,
#         'relativeDirection': 'DEPART',
#         'streetName': 'path',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': -122.66147928202372,
#         'lat': 45.54204183875245,
#         'elevation': [{'first': 5.118, 'second': 51.92284458479429},
#          {'first': 13.608, 'second': 51.81284458479429}]},
#        {'distance': 18.568,
#         'relativeDirection': 'LEFT',
#         'streetName': 'NE Martin Luther King Junior Blvd',
#         'absoluteDirection': 'SOUTH',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.661654,
#         'lat': 45.5420409,
#         'elevation': [{'first': 0.0, 'second': 51.81284458479429},
#          {'first': 10.0, 'second': 51.59284458479429},
#          {'first': 18.57, 'second': 51.3928445847943}]},
#        {'distance': 239.11399999999998,
#         'relativeDirection': 'RIGHT',
#         'streetName': 'NE Knott St',
#         'absoluteDirection': 'WEST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': False,
#         'lon': -122.6616462,
#         'lat': 45.541874,
#         'elevation': [{'first': 0.0, 'second': 51.3928445847943},
#          {'first': 10.0, 'second': 51.402844584794295},
#          {'first': 20.0, 'second': 51.432844584794296},
#          {'first': 30.0, 'second': 51.3828445847943},
#          {'first': 40.0, 'second': 51.34284458479429},
#          {'first': 48.48, 'second': 51.31284458479429},
#          {'first': 48.481, 'second': 51.31284458479429},
#          {'first': 58.481, 'second': 51.2828445847943},
#          {'first': 67.451, 'second': 51.222844584794295},
#          {'first': 67.452, 'second': 51.222844584794295},
#          {'first': 81.462, 'second': 51.31284458479429},
#          {'first': 81.462, 'second': 51.31284458479429},
#          {'first': 92.982, 'second': 51.1328445847943},
#          {'first': 92.98, 'second': 51.1328445847943},
#          {'first': 102.98, 'second': 51.402844584794295},
#          {'first': 112.98, 'second': 51.2728445847943},
#          {'first': 124.83000000000001, 'second': 51.1628445847943},
#          {'first': 124.825, 'second': 51.1628445847943},
#          {'first': 134.825, 'second': 50.6428445847943},
#          {'first': 144.825, 'second': 50.622844584794294},
#          {'first': 154.825, 'second': 50.4628445847943},
#          {'first': 164.825, 'second': 50.372844584794294},
#          {'first': 174.825, 'second': 50.1428445847943},
#          {'first': 184.825, 'second': 50.0528445847943},
#          {'first': 193.765, 'second': 49.9428445847943},
#          {'first': 193.765, 'second': 49.9428445847943},
#          {'first': 203.765, 'second': 49.972844584794295},
#          {'first': 213.765, 'second': 49.9428445847943},
#          {'first': 223.765, 'second': 49.9128445847943},
#          {'first': 233.765, 'second': 49.8928445847943},
#          {'first': 239.11499999999998, 'second': 49.8228445847943}]}]}],
#     'tooSloped': False}]},
#  'debugOutput': {'precalculationTime': 99,
#   'pathCalculationTime': 137,
#   'pathTimes': [51, 52, 34],
#   'renderingTime': 3,
#   'totalTime': 239,
#   'timedOut': False},
#  'elevationMetadata': {'ellipsoidToGeoidDifference': -19.522844584794296,
#   'geoidElevation': True}}

# %%
json_content['plan']['itineraries'][0]
# Out:
# {'duration': 2409,
#  'startTime': 1683054085000,
#  'endTime': 1683056494000,
#  'walkTime': 713,
#  'transitTime': 1283,
#  'waitingTime': 413,
#  'walkDistance': 1007.4454626807768,
#  'walkLimitExceeded': False,
#  'elevationLost': 0.8899999999999979,
#  'elevationGained': 11.54,
#  'transfers': 1,
#  'fare': {'fare': {'regular': {'currency': {'symbol': '$',
#      'currency': 'USD',
#      'defaultFractionDigits': 2,
#      'currencyCode': 'USD'},
#     'cents': 450}},
#   'details': {'regular': []}},
#  'legs': [{'startTime': 1683054085000,
#    'endTime': 1683054162000,
#    'departureDelay': 0,
#    'arrivalDelay': 0,
#    'realTime': False,
#    'distance': 69.472,
#    'pathway': False,
#    'mode': 'WALK',
#    'route': '',
#    'agencyTimeZoneOffset': -25200000,
#    'interlineWithPreviousLeg': False,
#    'from': {'name': 'Origin',
#     'wheelchairBoarding': 'UNKNOWN',
#     'lon': -122.646199,
#     'lat': 45.504286,
#     'departure': 1683054085000,
#     'orig': '',
#     'vertexType': 'NORMAL'},
#    'to': {'name': 'SE Division & 20th Ave',
#     'stopId': 'TriMet:14243',
#     'wheelchairBoarding': 'UNKNOWN',
#     'stopCode': '14243',
#     'lon': -122.645979,
#     'lat': 45.504888,
#     'arrival': 1683054162000,
#     'departure': 1683054163000,
#     'zoneId': 'B',
#     'stopIndex': 31,
#     'stopSequence': 33,
#     'vertexType': 'TRANSIT',
#     'boardAlightType': 'DEFAULT'},
#    'legGeometry': {'points': 'wpvtGtgqkVkB??T??', 'length': 4},
#    'rentedBike': False,
#    'rentedCar': False,
#    'rentedVehicle': False,
#    'hailedCar': False,
#    'flexDrtAdvanceBookMin': 0.0,
#    'duration': 77.0,
#    'transitLeg': False,
#    'steps': [{'distance': 60.254,
#      'relativeDirection': 'DEPART',
#      'streetName': 'parking aisle',
#      'absoluteDirection': 'NORTH',
#      'stayOn': False,
#      'area': False,
#      'bogusName': True,
#      'lon': -122.64586757989295,
#      'lat': 45.50428423350078,
#      'elevation': [{'first': 0.0, 'second': 16.842844584794296},
#       {'first': 10.0, 'second': 16.812844584794295},
#       {'first': 20.0, 'second': 16.822844584794296},
#       {'first': 30.0, 'second': 16.832844584794294},
#       {'first': 40.0, 'second': 16.822844584794296},
#       {'first': 50.0, 'second': 16.902844584794295},
#       {'first': 60.0, 'second': 17.072844584794296},
#       {'first': 60.25, 'second': 17.072844584794296}]},
#     {'distance': 9.218,
#      'relativeDirection': 'LEFT',
#      'streetName': 'SE Division St',
#      'absoluteDirection': 'WEST',
#      'stayOn': False,
#      'area': False,
#      'bogusName': False,
#      'lon': -122.6458617,
#      'lat': 45.5048261,
#      'elevation': []}]},
#   {'startTime': 1683054163000,
#    'endTime': 1683054486000,
#    'departureDelay': 0,
#    'arrivalDelay': 0,
#    'realTime': False,
#    'distance': 1558.7326850334389,
#    'pathway': False,
#    'mode': 'BUS',
#    'route': 'FX2',
#    'agencyName': 'TriMet',
#    'agencyUrl': 'https://trimet.org/',
#    'agencyTimeZoneOffset': -25200000,
#    'routeColor': '61A60E',
#    'routeType': 3,
#    'routeId': 'TriMet:2',
#    'routeTextColor': 'FFFFFF',
#    'interlineWithPreviousLeg': False,
#    'tripBlockId': '253',
#    'headsign': 'Portland',
#    'agencyId': 'TRIMET',
#    'tripId': 'TriMet:12336945',
#    'serviceDate': '20230502',
#    'from': {'name': 'SE Division & 20th Ave',
#     'stopId': 'TriMet:14243',
#     'wheelchairBoarding': 'UNKNOWN',
#     'stopCode': '14243',
#     'lon': -122.645979,
#     'lat': 45.504888,
#     'arrival': 1683054162000,
#     'departure': 1683054163000,
#     'zoneId': 'B',
#     'stopIndex': 31,
#     'stopSequence': 33,
#     'vertexType': 'TRANSIT',
#     'boardAlightType': 'DEFAULT'},
#    'to': {'name': 'OMSI/SE Water',
#     'stopId': 'TriMet:13773',
#     'wheelchairBoarding': 'UNKNOWN',
#     'stopCode': '13773',
#     'lon': -122.663155,
#     'lat': 45.506602,
#     'arrival': 1683054486000,
#     'departure': 1683054486000,
#     'zoneId': 'B',
#     'stopIndex': 33,
#     'stopSequence': 35,
#     'vertexType': 'TRANSIT',
#     'boardAlightType': 'DEFAULT'},
#    'legGeometry': {'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@AvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVR@FBDBDDTRDDTPHFLFD?XG?zDyCAU@G?I@GDC@CBILKVM\\Qd@IZK^I`@I^EXEZEZC\\CZ?VCX?T?V?|A?j@@T?V?PAhE',
#     'length': 77},
#    'interStopGeometry': [{'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@',
#      'length': 20},
#     {'points': 'ktvtGxaskVAvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVR@FBDBDDTRDDTPHFLFD?XG?zDyCAU@G?I@GDC@CBILKVM\\Qd@IZK^I`@I^EXEZEZC\\CZ?VCX?T?V?|A?j@@T?V?PAhE',
#      'length': 58}],
#    'routeShortName': 'FX2',
#    'routeLongName': 'Division',
#    'rentedBike': False,
#    'rentedCar': False,
#    'rentedVehicle': False,
#    'hailedCar': False,
#    'flexDrtAdvanceBookMin': 0.0,
#    'duration': 323.0,
#    'transitLeg': True,
#    'steps': []},
#   {'startTime': 1683054486000,
#    'endTime': 1683054549000,
#    'departureDelay': 0,
#    'arrivalDelay': 0,
#    'realTime': False,
#    'distance': 80.857,
#    'pathway': False,
#    'mode': 'WALK',
#    'route': '',
#    'agencyTimeZoneOffset': -25200000,
#    'interlineWithPreviousLeg': False,
#    'from': {'name': 'OMSI/SE Water',
#     'stopId': 'TriMet:13773',
#     'wheelchairBoarding': 'UNKNOWN',
#     'stopCode': '13773',
#     'lon': -122.663155,
#     'lat': 45.506602,
#     'arrival': 1683054486000,
#     'departure': 1683054486000,
#     'zoneId': 'B',
#     'stopIndex': 33,
#     'stopSequence': 35,
#     'vertexType': 'TRANSIT',
#     'boardAlightType': 'DEFAULT'},
#    'to': {'name': 'SE Water/OMSI (Streetcar)',
#     'stopId': 'TriMet:13615',
#     'wheelchairBoarding': 'UNKNOWN',
#     'stopCode': '13615',
#     'lon': -122.663345,
#     'lat': 45.507038,
#     'arrival': 1683054549000,
#     'departure': 1683054960000,
#     'zoneId': 'B',
#     'stopIndex': 15,
#     'stopSequence': 16,
#     'vertexType': 'TRANSIT',
#     'boardAlightType': 'DEFAULT'},
#    'legGeometry': {'points': 'e_wtGvstkV?PC??`@E?I?A?AE?KIFABCDCCCCC?AAE?C@?EW?',
#     'length': 20},
#    'rentedBike': False,
#    'rentedCar': False,
#    'rentedVehicle': False,
#    'hailedCar': False,
#    'flexDrtAdvanceBookMin': 0.0,
#    'duration': 63.0,
#    'transitLeg': False,
#    'steps': [{'distance': 9.343,
#      'relativeDirection': 'DEPART',
#      'streetName': 'OMSI/SE Water',
#      'absoluteDirection': 'WEST',
#      'stayOn': False,
#      'area': False,
#      'bogusName': False,
#      'lon': -122.66315529256174,
#      'lat': 45.50659372635657,
#      'elevation': [{'first': 7.063, 'second': 11.972844584794295},
#       {'first': 9.343, 'second': 11.972844584794295}]},
#     {'distance': 13.244,
#      'relativeDirection': 'LEFT',
#      'streetName': 'path',
#      'absoluteDirection': 'WEST',
#      'stayOn': False,
#      'area': False,
#      'bogusName': True,
#      'lon': -122.6632452,
#      'lat': 45.5066158,
#      'elevation': [{'first': 0.0, 'second': 11.972844584794295},
#       {'first': 13.24, 'second': 11.582844584794294}]},
#     {'distance': 42.755,
#      'relativeDirection': 'UTURN_RIGHT',
#      'streetName': 'path',
#      'absoluteDirection': 'EAST',
#      'stayOn': True,
#      'area': False,
#      'bogusName': True,
#      'lon': -122.6634135,
#      'lat': 45.5067045,
#      'elevation': [{'first': 0.0, 'second': 11.572844584794296},
#       {'first': 7.21, 'second': 11.582844584794294},
#       {'first': 7.205, 'second': 11.582844584794294},
#       {'first': 18.825, 'second': 11.552844584794297},
#       {'first': 18.822000000000003, 'second': 11.552844584794297},
#       {'first': 33.222, 'second': 11.472844584794295}]},
#     {'distance': 15.515,
#      'relativeDirection': 'RIGHT',
#      'streetName': 'SE Water/OMSI',
#      'absoluteDirection': 'EAST',
#      'stayOn': False,
#      'area': True,
#      'bogusName': False,
#      'lon': -122.6633713,
#      'lat': 45.5069134,
#      'elevation': []}]},
#   {'startTime': 1683054960000,
#    'endTime': 1683055920000,
#    'departureDelay': 0,
#    'arrivalDelay': 0,
#    'realTime': False,
#    'distance': 3454.115446597877,
#    'pathway': False,
#    'mode': 'TRAM',
#    'route': 'Portland Streetcar - B Loop',
#    'agencyName': 'Portland Streetcar',
#    'agencyUrl': 'https://portlandstreetcar.org/',
#    'agencyTimeZoneOffset': -25200000,
#    'routeColor': '3E0099',
#    'routeType': 0,
#    'routeId': 'TriMet:195',
#    'routeTextColor': 'FFFFFF',
#    'interlineWithPreviousLeg': False,
#    'tripBlockId': '58',
#    'headsign': 'PSU via Pearl',
#    'agencyId': 'PSC',
#    'tripId': 'TriMet:12352153',
#    'serviceDate': '20230502',
#    'from': {'name': 'SE Water/OMSI (Streetcar)',
#     'stopId': 'TriMet:13615',
#     'wheelchairBoarding': 'UNKNOWN',
#     'stopCode': '13615',
#     'lon': -122.663345,
#     'lat': 45.507038,
#     'arrival': 1683054549000,
#     'departure': 1683054960000,
#     'zoneId': 'B',
#     'stopIndex': 15,
#     'stopSequence': 16,
#     'vertexType': 'TRANSIT',
#     'boardAlightType': 'DEFAULT'},
#    'to': {'name': 'NE Broadway & 2nd (Streetcar)',
#     'stopId': 'TriMet:13618',
#     'wheelchairBoarding': 'UNKNOWN',
#     'stopCode': '13618',
#     'lon': -122.663538,
#     'lat': 45.535034,
#     'arrival': 1683055920000,
#     'departure': 1683055921000,
#     'zoneId': 'B',
#     'stopIndex': 26,
#     'stopSequence': 27,
#     'vertexType': 'TRANSIT',
#     'boardAlightType': 'DEFAULT'},
#    'legGeometry': {'points': '}awtGxttkVE?I?k@?G?GAUKKGIIECMQIOeBqDMUCGEEEGIGGEGEIEIAICOAM@I@]HE?G?C?ICECCCEECECGCIAGAI?I?q@?W?I?EAGCICCACCEeA?g@?E?K?KAQ?qB?o@?}AAW?s@?]?e@?uBAC?O?S?cA?_@?Y?S?yBA{B?C?M?M?O?u@?M?k@AO?O?oBAW?m@?K?A?g@?S?Q?O?kB@q@A{A?cBA[?M?s@?{A?u@?y@?_@?w@Ai@?i@?}B?O?OAo@?A?u@?W?mC?mCAS?{B?UBiD?c@?MA]CU?_AAq@?]?M?c@?wA?}@?g@?U?I?CAM?mB?K?[?e@?M???W?_@AM?E?iC?yBAS?eA?iA?mCAmC?M?qBAO?C@K?q@AS?c@?SAAV?\\?v@?t@?N?XAX?nD?lD',
#     'length': 168},
#    'interStopGeometry': [{'points': '}awtGxttkVE?I?k@?G?GAUKKGIIECMQIOeBqDMUCGEEEGIGGEGEIEIAICOAM@I@]HE?G?C?ICECCCEECECGCIAGAI?I?q@?W?I?EAGCICCACCEeA?g@?',
#      'length': 51},
#     {'points': 'otwtG`etkVE?K?KAQ?qB?o@?}AAW?s@?]?e@?uBA', 'length': 13},
#     {'points': 'efxtGzdtkVC?O?S?cA?_@?Y?S?yBA{B?', 'length': 10},
#     {'points': 'usxtGxdtkVC?M?M?O?u@?M?k@AO?O?oBAW?m@?', 'length': 13},
#     {'points': 'k_ytGtdtkVK?A?g@?S?Q?O?kB@q@A{A?cBA[?M?s@?', 'length': 14},
#     {'points': 'spytGrdtkV{A?u@?y@?_@?w@Ai@?i@?}B?O?OAo@?A?u@?', 'length': 14},
#     {'points': 'qdztGndtkVW?mC?mCAS?{B?UBiD?c@?MA]CU?_AAq@?]?M?c@?',
#      'length': 17},
#     {'points': '}a{tGhdtkVwA?}@?g@?U?I?CAM?mB?K?[?e@?M???', 'length': 14},
#     {'points': 'wo{tGfdtkVW?_@AM?E?iC?yBAS?eA?', 'length': 9},
#     {'points': 'a}{tGbdtkViA?mCAmC?M?qBAO?C@K?q@AS?', 'length': 11},
#     {'points': 'mo|tG~ctkVc@?SAAV?\\?v@?t@?N?XAX?nD?lD', 'length': 12}],
#    'routeLongName': 'Portland Streetcar - B Loop',
#    'rentedBike': False,
#    'rentedCar': False,
#    'rentedVehicle': False,
#    'hailedCar': False,
#    'flexDrtAdvanceBookMin': 0.0,
#    'duration': 960.0,
#    'transitLeg': True,
#    'steps': []},
#   {'startTime': 1683055921000,
#    'endTime': 1683056494000,
#    'departureDelay': 0,
#    'arrivalDelay': 0,
#    'realTime': False,
#    'distance': 856.8840000000001,
#    'pathway': False,
#    'mode': 'WALK',
#    'route': '',
#    'agencyTimeZoneOffset': -25200000,
#    'interlineWithPreviousLeg': False,
#    'from': {'name': 'NE Broadway & 2nd (Streetcar)',
#     'stopId': 'TriMet:13618',
#     'wheelchairBoarding': 'UNKNOWN',
#     'stopCode': '13618',
#     'lon': -122.663538,
#     'lat': 45.535034,
#     'arrival': 1683055920000,
#     'departure': 1683055921000,
#     'zoneId': 'B',
#     'stopIndex': 26,
#     'stopSequence': 27,
#     'vertexType': 'TRANSIT',
#     'boardAlightType': 'DEFAULT'},
#    'to': {'name': 'Destination',
#     'wheelchairBoarding': 'UNKNOWN',
#     'lon': -122.664715,
#     'lat': 45.542102,
#     'arrival': 1683056494000,
#     'orig': '',
#     'vertexType': 'NORMAL'},
#    'legGeometry': {'points': '}p|tGbvtkV?D?@C@G??PQ?Q?Q?_@?u@AoC??dBoB?c@?O?kC?w@AgCAaE?aA?}BAw@?gCA@`B?P',
#     'length': 26},
#    'rentedBike': False,
#    'rentedCar': False,
#    'rentedVehicle': False,
#    'hailedCar': False,
#    'flexDrtAdvanceBookMin': 0.0,
#    'duration': 573.0,
#    'transitLeg': False,
#    'steps': [{'distance': 3.254,
#      'relativeDirection': 'DEPART',
#      'streetName': 'path',
#      'absoluteDirection': 'WEST',
#      'stayOn': False,
#      'area': False,
#      'bogusName': True,
#      'lon': -122.66353797686243,
#      'lat': 45.5350370105401,
#      'elevation': [{'first': 1.845, 'second': 39.402844584794295},
#       {'first': 3.255, 'second': 39.372844584794294}]},
#     {'distance': 6.866,
#      'relativeDirection': 'RIGHT',
#      'streetName': 'path',
#      'absoluteDirection': 'NORTH',
#      'stayOn': True,
#      'area': False,
#      'bogusName': True,
#      'lon': -122.6635798,
#      'lat': 45.5350372,
#      'elevation': [{'first': 0.0, 'second': 39.372844584794294},
#       {'first': 6.87, 'second': 39.3528445847943}]},
#     {'distance': 7.282,
#      'relativeDirection': 'LEFT',
#      'streetName': 'NE Broadway',
#      'absoluteDirection': 'WEST',
#      'stayOn': False,
#      'area': False,
#      'bogusName': False,
#      'lon': -122.663586,
#      'lat': 45.5350988,
#      'elevation': [{'first': 0.0, 'second': 39.3528445847943},
#       {'first': 7.28, 'second': 39.3028445847943}]},
#     {'distance': 156.909,
#      'relativeDirection': 'RIGHT',
#      'streetName': 'NE 2nd Ave',
#      'absoluteDirection': 'NORTH',
#      'stayOn': False,
#      'area': False,
#      'bogusName': False,
#      'lon': -122.6636795,
#      'lat': 45.5350989,
#      'elevation': [{'first': 0.0, 'second': 39.3028445847943},
#       {'first': 10.0, 'second': 39.5728445847943},
#       {'first': 19.32, 'second': 39.5228445847943},
#       {'first': 19.315, 'second': 39.5228445847943},
#       {'first': 29.555, 'second': 39.5728445847943},
#       {'first': 29.556, 'second': 39.5728445847943},
#       {'first': 39.556, 'second': 39.612844584794296},
#       {'first': 47.106, 'second': 39.652844584794295},
#       {'first': 47.103, 'second': 39.652844584794295},
#       {'first': 57.103, 'second': 39.7128445847943},
#       {'first': 67.10300000000001, 'second': 39.7728445847943},
#       {'first': 77.503, 'second': 39.81284458479429},
#       {'first': 77.505, 'second': 39.81284458479429},
#       {'first': 87.505, 'second': 39.84284458479429},
#       {'first': 97.505, 'second': 39.9128445847943},
#       {'first': 107.505, 'second': 39.9928445847943},
#       {'first': 117.505, 'second': 40.09284458479429},
#       {'first': 127.505, 'second': 40.1928445847943},
#       {'first': 137.505, 'second': 40.2828445847943},
#       {'first': 147.505, 'second': 40.3828445847943},
#       {'first': 156.905, 'second': 40.5228445847943}]},
#     {'distance': 39.675,
#      'relativeDirection': 'LEFT',
#      'streetName': 'NE Hancock St',
#      'absoluteDirection': 'WEST',
#      'stayOn': False,
#      'area': False,
#      'bogusName': False,
#      'lon': -122.66367,
#      'lat': 45.53651,
#      'elevation': [{'first': 0.0, 'second': 40.5228445847943},
#       {'first': 10.0, 'second': 40.862844584794296},
#       {'first': 20.0, 'second': 41.0528445847943},
#       {'first': 30.0, 'second': 41.0228445847943},
#       {'first': 39.68, 'second': 40.84284458479429}]},
#     {'distance': 597.549,
#      'relativeDirection': 'RIGHT',
#      'streetName': 'NE Rodney Ave',
#      'absoluteDirection': 'NORTH',
#      'stayOn': False,
#      'area': False,
#      'bogusName': False,
#      'lon': -122.6641794,
#      'lat': 45.5365107,
#      'elevation': [{'first': 0.0, 'second': 40.84284458479429},
#       {'first': 10.0, 'second': 40.502844584794296},
#       {'first': 20.0, 'second': 40.5328445847943},
#       {'first': 30.0, 'second': 40.6328445847943},
#       {'first': 40.0, 'second': 40.762844584794294},
#       {'first': 50.0, 'second': 40.862844584794296},
#       {'first': 62.69, 'second': 41.002844584794296},
#       {'first': 62.692, 'second': 41.002844584794296},
#       {'first': 72.69200000000001, 'second': 41.112844584794296},
#       {'first': 82.202, 'second': 41.182844584794296},
#       {'first': 82.206, 'second': 41.182844584794296},
#       {'first': 92.206, 'second': 41.292844584794295},
#       {'first': 102.206, 'second': 41.3928445847943},
#       {'first': 112.206, 'second': 41.4928445847943},
#       {'first': 122.206, 'second': 41.622844584794294},
#       {'first': 132.20600000000002, 'second': 41.752844584794296},
#       {'first': 142.20600000000002, 'second': 41.872844584794294},
#       {'first': 152.20600000000002, 'second': 41.98284458479429},
#       {'first': 162.20600000000002, 'second': 42.1028445847943},
#       {'first': 169.316, 'second': 42.20284458479429},
#       {'first': 169.316, 'second': 42.20284458479429},
#       {'first': 179.316, 'second': 42.332844584794294},
#       {'first': 189.316, 'second': 42.542844584794295},
#       {'first': 199.316, 'second': 42.84284458479429},
#       {'first': 209.316, 'second': 43.182844584794296},
#       {'first': 219.316, 'second': 43.5228445847943},
#       {'first': 229.316, 'second': 43.872844584794294},
#       {'first': 239.316, 'second': 44.23284458479429},
#       {'first': 249.316, 'second': 44.5528445847943},
#       {'first': 259.31600000000003, 'second': 44.8928445847943},
#       {'first': 269.31600000000003, 'second': 45.252844584794296},
#       {'first': 276.466, 'second': 45.472844584794295},
#       {'first': 276.468, 'second': 45.472844584794295},
#       {'first': 286.468, 'second': 45.682844584794296},
#       {'first': 296.468, 'second': 45.70284458479429},
#       {'first': 306.468, 'second': 45.81284458479429},
#       {'first': 316.468, 'second': 45.872844584794294},
#       {'first': 326.468, 'second': 45.95284458479429},
#       {'first': 336.468, 'second': 46.042844584794295},
#       {'first': 346.468, 'second': 46.09284458479429},
#       {'first': 356.468, 'second': 46.182844584794296},
#       {'first': 366.468, 'second': 46.2728445847943},
#       {'first': 376.468, 'second': 46.31284458479429},
#       {'first': 383.678, 'second': 46.4128445847943},
#       {'first': 383.682, 'second': 46.4128445847943},
#       {'first': 393.682, 'second': 46.5328445847943},
#       {'first': 403.682, 'second': 46.67284458479429},
#       {'first': 413.682, 'second': 46.7728445847943},
#       {'first': 423.682, 'second': 46.862844584794296},
#       {'first': 433.682, 'second': 46.95284458479429},
#       {'first': 443.682, 'second': 47.0528445847943},
#       {'first': 453.682, 'second': 47.17284458479429},
#       {'first': 463.682, 'second': 47.262844584794294},
#       {'first': 473.682, 'second': 47.332844584794294},
#       {'first': 483.682, 'second': 47.42284458479429},
#       {'first': 491.002, 'second': 47.4928445847943},
#       {'first': 490.999, 'second': 47.4928445847943},
#       {'first': 500.999, 'second': 47.7128445847943},
#       {'first': 510.999, 'second': 47.73284458479429},
#       {'first': 522.089, 'second': 47.98284458479429},
#       {'first': 522.09, 'second': 47.98284458479429},
#       {'first': 532.09, 'second': 48.2428445847943},
#       {'first': 542.09, 'second': 48.4928445847943},
#       {'first': 552.09, 'second': 48.752844584794296},
#       {'first': 562.09, 'second': 49.002844584794296},
#       {'first': 572.09, 'second': 49.262844584794294},
#       {'first': 582.09, 'second': 49.5328445847943},
#       {'first': 592.09, 'second': 49.792844584794295},
#       {'first': 597.5500000000001, 'second': 49.9428445847943}]},
#     {'distance': 45.349,
#      'relativeDirection': 'LEFT',
#      'streetName': 'NE Knott St',
#      'absoluteDirection': 'WEST',
#      'stayOn': False,
#      'area': False,
#      'bogusName': False,
#      'lon': -122.6641342,
#      'lat': 45.5418845,
#      'elevation': [{'first': 0.0, 'second': 49.9428445847943},
#       {'first': 10.0, 'second': 49.972844584794295},
#       {'first': 20.0, 'second': 49.9428445847943},
#       {'first': 30.0, 'second': 49.9128445847943},
#       {'first': 40.0, 'second': 49.8928445847943},
#       {'first': 45.35, 'second': 49.8228445847943}]}]}],
#  'tooSloped': False}

# %%
route_id = json_content['plan']['itineraries'][1]['legs'][1]['routeId'].split(":")[-1]
route_id
# Out:
# '2'

# %%
json_content['plan']['itineraries'][1]['legs'][1]['from']
# Out:
# {'name': 'SE Division & 20th Ave',
#  'stopId': 'TriMet:14243',
#  'wheelchairBoarding': 'UNKNOWN',
#  'stopCode': '14243',
#  'lon': -122.645979,
#  'lat': 45.504888,
#  'arrival': 1683054162000,
#  'departure': 1683054163000,
#  'zoneId': 'B',
#  'stopIndex': 31,
#  'stopSequence': 33,
#  'vertexType': 'TRANSIT',
#  'boardAlightType': 'DEFAULT'}

# %%
json_content['plan']['itineraries'][1]['legs'][1]['to']
# Out:
# {'name': 'SW 6th & Taylor',
#  'stopId': 'TriMet:7800',
#  'wheelchairBoarding': 'UNKNOWN',
#  'stopCode': '7800',
#  'lon': -122.679316,
#  'lat': 45.517604,
#  'arrival': 1683055200000,
#  'departure': 1683055200000,
#  'zoneId': 'B',
#  'stopIndex': 38,
#  'stopSequence': 40,
#  'vertexType': 'TRANSIT',
#  'boardAlightType': 'DEFAULT'}

# %% [markdown]
# path for that leg

# %%
polyline.decode(json_content['plan']['itineraries'][1]['legs'][1]['legGeometry']['points'])[:10]
# Out:
# [(45.50482, -122.64601),
#  (45.50482, -122.64607),
#  (45.50483, -122.6469),
#  (45.50483, -122.64765),
#  (45.50483, -122.64856),
#  (45.50483, -122.64867),
#  (45.50483, -122.64875),
#  (45.50483, -122.64944),
#  (45.50484, -122.64968),
#  (45.50484, -122.65069)]

# %%
len(polyline.decode(json_content['plan']['itineraries'][1]['legs'][1]['legGeometry']['points']))
# Out:
# 278

# %%
reformatted_coords = []
original_coords = polyline.decode(json_content['plan']['itineraries'][1]['legs'][1]['legGeometry']['points'])
for coord in original_coords:
    reformatted_coords.append((coord[1],coord[0]))

reformatted_coords[:5]
# Out:
# [(-122.64601, 45.50482),
#  (-122.64607, 45.50482),
#  (-122.6469, 45.50483),
#  (-122.64765, 45.50483),
#  (-122.64856, 45.50483)]

# %%
path_geometry = LineString(reformatted_coords)
path_geometry

# %%
path_gdf = gpd.GeoDataFrame(pd.DataFrame([route_id],columns=['route_id']), crs="4326", geometry=[path_geometry])
path_gdf
# Out:
#   route_id                                           geometry
# 0        2  LINESTRING (-122.64601 45.50482, -122.64607 45...

# %%
path_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cc9a79c9068baa67b30ab684612167e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cc9a79c9068baa67b30ab684612167e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cc9a79c9068baa67b30ab684612167e = L.map(
#                 &quot;map_0cc9a79c9068baa67b30ab684612167e&quot;,
#                 {
#                     center: [45.51007, -122.664665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0cc9a79c9068baa67b30ab684612167e);
#
#
#
#
#
#             var tile_layer_d8aaacda49581052e165cb5e1ee0a7d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0cc9a79c9068baa67b30ab684612167e);
#
#
#             map_0cc9a79c9068baa67b30ab684612167e.fitBounds(
#                 [[45.50251, -122.68332], [45.51763, -122.64601]],
#                 {}
#             );
#
#
#         function geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a9a8aa88dfd8081cc7c4c586f1220e95.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a9a8aa88dfd8081cc7c4c586f1220e95 = L.geoJson(null, {
#                 onEachFeature: geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_onEachFeature,
#
#                 style: geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_styler,
#                 pointToLayer: geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_pointToLayer
#         });
#
#         function geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_add (data) {
#             geo_json_a9a8aa88dfd8081cc7c4c586f1220e95
#                 .addData(data)
#                 .addTo(map_0cc9a79c9068baa67b30ab684612167e);
#         }
#             geo_json_a9a8aa88dfd8081cc7c4c586f1220e95_add({&quot;bbox&quot;: [-122.68332, 45.50251, -122.64601, 45.51763], &quot;features&quot;: [{&quot;bbox&quot;: [-122.68332, 45.50251, -122.64601, 45.51763], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.64601, 45.50482], [-122.64607, 45.50482], [-122.6469, 45.50483], [-122.64765, 45.50483], [-122.64856, 45.50483], [-122.64867, 45.50483], [-122.64875, 45.50483], [-122.64944, 45.50483], [-122.64968, 45.50484], [-122.65069, 45.50484], [-122.65171, 45.50484], [-122.6518, 45.50484], [-122.65193, 45.50484], [-122.65272, 45.50485], [-122.65373, 45.50485], [-122.65384, 45.50485], [-122.65399, 45.50485], [-122.65476, 45.50486], [-122.65485, 45.50486], [-122.65517, 45.50486], [-122.65577, 45.50487], [-122.65588, 45.50487], [-122.65596, 45.50487], [-122.65604, 45.50488], [-122.6561, 45.50489], [-122.65616,

# %%
path_gdf.to_file("test.geojson", driver="GeoJSON")

# %%
winning_dict = {}
for idx, itinerary in enumerate(json_content['plan']['itineraries']):
    winning_combos = []
    for leg in itinerary['legs']:
        if leg['mode'] != 'WALK':
            winning_combos.append((leg['mode'],leg['route']))
    winning_dict[idx] = winning_combos

# %%
winning_dict
# Out:
# {0: [('BUS', 'FX2'), ('TRAM', 'Portland Streetcar - B Loop')],
#  1: [('BUS', 'FX2'), ('BUS', '4')],
#  2: [('BUS', '10'), ('BUS', '6')]}

# %%
for leg in json_content['plan']['itineraries'][0]['legs']:
    print(leg['mode'])
# Out:
# WALK
# BUS
# WALK
# BUS
# WALK

# %%
json_content['plan']['itineraries'][0]['legs'][1]
# Out:
# {'startTime': 1683054163000,
#  'endTime': 1683055200000,
#  'departureDelay': 0,
#  'arrivalDelay': 0,
#  'realTime': False,
#  'distance': 4811.395650329354,
#  'pathway': False,
#  'mode': 'BUS',
#  'route': 'FX2',
#  'agencyName': 'TriMet',
#  'agencyUrl': 'https://trimet.org/',
#  'agencyTimeZoneOffset': -25200000,
#  'routeColor': '61A60E',
#  'routeType': 3,
#  'routeId': 'TriMet:2',
#  'routeTextColor': 'FFFFFF',
#  'interlineWithPreviousLeg': False,
#  'tripBlockId': '253',
#  'headsign': 'Portland',
#  'agencyId': 'TRIMET',
#  'tripId': 'TriMet:12336945',
#  'serviceDate': '20230502',
#  'from': {'name': 'SE Division & 20th Ave',
#   'stopId': 'TriMet:14243',
#   'wheelchairBoarding': 'UNKNOWN',
#   'stopCode': '14243',
#   'lon': -122.645979,
#   'lat': 45.504888,
#   'arrival': 1683054162000,
#   'departure': 1683054163000,
#   'zoneId': 'B',
#   'stopIndex': 31,
#   'stopSequence': 33,
#   'vertexType': 'TRANSIT',
#   'boardAlightType': 'DEFAULT'},
#  'to': {'name': 'SW 6th & Taylor',
#   'stopId': 'TriMet:7800',
#   'wheelchairBoarding': 'UNKNOWN',
#   'stopCode': '7800',
#   'lon': -122.679316,
#   'lat': 45.517604,
#   'arrival': 1683055200000,
#   'departure': 1683055200000,
#   'zoneId': 'B',
#   'stopIndex': 38,
#   'stopSequence': 40,
#   'vertexType': 'TRANSIT',
#   'boardAlightType': 'DEFAULT'},
#  'legGeometry': {'points': 'ctvtGphqkV?JAdD?tC?tD?T?N?hCAn@?hE?jE?P?XA|C?hE?T?\\AxC?P?~@AvB?T?NANAJAJCFENOZs@zAKDWh@?LMZKVR@FBDBDDTRDDTPHFLFD?XG?zDyCAU@G?I@GDC@CBILKVM\\Qd@IZK^I`@I^EXEZEZC\\CZ?VCX?T?V?|A?j@@T?V?PA